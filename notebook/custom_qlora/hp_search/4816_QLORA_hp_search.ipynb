# %%
# !git clone https://github.com/VietAnh-AI2-UET/ViT5_Base_QLoRa_VNDS.git
# Out:
# Cloning into 'ViT5_Base_QLoRa_VNDS'...
# remote: Enumerating objects: 222, done.
# remote: Counting objects: 100% (222/222), done.
# remote: Compressing objects: 100% (154/154), done.
# remote: Total 222 (delta 85), reused 176 (delta 41), pack-reused 0 (from 0)
# Receiving objects: 100% (222/222), 205.92 KiB | 6.43 MiB/s, done.
# Resolving deltas: 100% (85/85), done.

# %%
# %cd ViT5_Base_QLoRa_VNDS
# Out:
# /content/ViT5_Base_QLoRa_VNDS

# %%
# !git checkout customize
# Out:
# Branch 'customize' set up to track remote branch 'customize' from 'origin'.
# Switched to a new branch 'customize'

# %%
# !chmod +x runner/hp_search_runner.sh

# %%
# !./runner/hp_search_runner.sh
# Out:
# === SETTING UP HYPERPARAMS SEARCHING EXPERIMENT ===
# Installing gettext library for bash
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# gettext is already the newest version (0.21-4ubuntu4).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# Installing requirements.txt
# Creating configs file at: configs/hp_search_exp/hp_search_configs.yaml
# Start running scripts/custom_qlora/hp_search.py
# 2026-03-17 02:24:37.008159: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773714277.028670    3591 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773714277.035734    3591 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773714277.053404    3591 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773714277.053430    3591 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773714277.053434    3591 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773714277.053439    3591 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-17 02:24:37.059095: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ===== RUNNING CUSTOMIZE_RANK.PY =====
# Step 0: Loading configuration for VietAI/vit5-base fine-tuning completed
# STEP 1: LOADING TOKENIZER AND DATASET COMPLETED
# Map: 100% 200/200 [00:00<00:00, 434.12 examples/s]
# STEP 2: PREPROCESSING DATA COMPLETED
# STEP 3: SETTING UP VietAI/vit5-base QUANTIZATION COMPLETED
#
# --- CHECKING LORA RANK DISTRIBUTION (LORA LAYERS) ---
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.2.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.2.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.3.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.3.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.3.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.3.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.4.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.q            | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.v            | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.q            | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.v            | Rank: 16
# --------------------------------------------------
#
# STEP 4: SETTING UP HYPERPARAMS COMPLETED
# /content/ViT5_Base_QLoRa_VNDS/scripts/custom_qlora/hp_search.py:234: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(
#
# --- CHECKING LORA RANK DISTRIBUTION (LORA LAYERS) ---
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.2.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.2.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.3.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.3.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.3.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.3.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.4.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.q            | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.v            | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.q            | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.v            | Rank: 16
# --------------------------------------------------
#
# ===== START HYPERPARAMS SEARCHING VietAI/vit5-base =====
# [I 2026-03-17 02:24:58,293] A new study created in memory with name: no-name-f55d8955-8fb2-49af-8f79-aaa27685e9e3
#
# --- CHECKING LORA RANK DISTRIBUTION (LORA LAYERS) ---
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.2.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.2.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.3.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.3.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.3.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.3.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.4.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.q            | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.v            | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.q            | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.v            | Rank: 16
# --------------------------------------------------
#
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# {'loss': 6.2007, 'grad_norm': 3.4960925579071045, 'learning_rate': 1.4494922443590888e-05, 'epoch': 0.4}
# {'loss': 5.8578, 'grad_norm': 3.3779540061950684, 'learning_rate': 1.1312978948637802e-05, 'epoch': 0.8}
#  50% 63/126 [03:46<05:37,  5.36s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:08,  2.72it/s]
#  12% 3/25 [00:01<00:11,  1.93it/s]
#  16% 4/25 [00:02<00:13,  1.58it/s]
#  20% 5/25 [00:03<00:13,  1.46it/s]
#  24% 6/25 [00:03<00:13,  1.43it/s]
#  28% 7/25 [00:04<00:13,  1.38it/s]
#  32% 8/25 [00:05<00:12,  1.33it/s]
#  36% 9/25 [00:06<00:14,  1.11it/s]
#  40% 10/25 [00:07<00:15,  1.03s/it]
#  44% 11/25 [00:09<00:14,  1.07s/it]
#  48% 12/25 [00:09<00:12,  1.00it/s]
#  52% 13/25 [00:10<00:10,  1.10it/s]
#  56% 14/25 [00:11<00:08,  1.28it/s]
#  60% 15/25 [00:11<00:07,  1.31it/s]
#  64% 16/25 [00:12<00:06,  1.34it/s]
#  68% 17/25 [00:13<00:05,  1.36it/s]
#  72% 18/25 [00:14<00:05,  1.36it/s]
#  76% 19/25 [00:14<00:04,  1.30it/s]
#  80% 20/25 [00:15<00:03,  1.32it/s]
#  84% 21/25 [00:16<00:03,  1.24it/s]
#  88% 22/25 [00:17<00:02,  1.26it/s]
#  92% 23/25 [00:17<00:01,  1.29it/s]
#  96% 24/25 [00:18<00:00,  1.33it/s]
#
# {'eval_loss': 5.713090419769287, 'eval_runtime': 20.2602, 'eval_samples_per_second': 9.872, 'eval_steps_per_second': 1.234, 'epoch': 1.0}
#  50% 63/126 [04:07<05:37,  5.36s/it]
# 100% 25/25 [00:19<00:00,  1.34it/s]
# {'loss': 5.7313, 'grad_norm': 2.383575677871704, 'learning_rate': 6.483761188223536e-06, 'epoch': 1.19}
# {'loss': 5.5962, 'grad_norm': 2.468714952468872, 'learning_rate': 2.115229782071115e-06, 'epoch': 1.59}
# {'loss': 5.5293, 'grad_norm': 2.343055009841919, 'learning_rate': 4.2227527116292823e-08, 'epoch': 1.99}
# 100% 126/126 [07:25<00:00,  2.58s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:07,  2.88it/s]
#  12% 3/25 [00:01<00:10,  2.02it/s]
#  16% 4/25 [00:02<00:12,  1.73it/s]
#  20% 5/25 [00:02<00:12,  1.64it/s]
#  24% 6/25 [00:03<00:12,  1.58it/s]
#  28% 7/25 [00:04<00:11,  1.54it/s]
#  32% 8/25 [00:04<00:11,  1.50it/s]
#  36% 9/25 [00:05<00:10,  1.48it/s]
#  40% 10/25 [00:06<00:10,  1.47it/s]
#  44% 11/25 [00:06<00:09,  1.54it/s]
#  48% 12/25 [00:07<00:08,  1.53it/s]
#  52% 13/25 [00:08<00:08,  1.50it/s]
#  56% 14/25 [00:08<00:06,  1.66it/s]
#  60% 15/25 [00:09<00:06,  1.61it/s]
#  64% 16/25 [00:09<00:05,  1.56it/s]
#  68% 17/25 [00:10<00:05,  1.53it/s]
#  72% 18/25 [00:11<00:04,  1.51it/s]
#  76% 19/25 [00:12<00:04,  1.49it/s]
#  80% 20/25 [00:12<00:03,  1.47it/s]
#  84% 21/25 [00:13<00:02,  1.46it/s]
#  88% 22/25 [00:14<00:02,  1.45it/s]
#  92% 23/25 [00:14<00:01,  1.45it/s]
#  96% 24/25 [00:15<00:00,  1.46it/s]
#
# {'eval_loss': 5.569281101226807, 'eval_runtime': 16.9171, 'eval_samples_per_second': 11.822, 'eval_steps_per_second': 1.478, 'epoch': 2.0}
# 100% 126/126 [07:42<00:00,  2.58s/it]
# 100% 25/25 [00:16<00:00,  1.46it/s]
# {'train_runtime': 462.802, 'train_samples_per_second': 4.322, 'train_steps_per_second': 0.272, 'train_loss': 5.780857510036892, 'epoch': 2.0}
# 100% 126/126 [07:42<00:00,  3.67s/it]
# [I 2026-03-17 02:32:45,449] Trial 0 finished with value: 5.569281101226807 and parameters: {'learning_rate': 1.516119565498593e-05}. Best is trial 0 with value: 5.569281101226807.
#
# --- CHECKING LORA RANK DISTRIBUTION (LORA LAYERS) ---
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.2.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.2.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.3.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.3.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.3.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.3.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.4.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.q            | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.v            | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.q            | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.v            | Rank: 16
# --------------------------------------------------
#
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# {'loss': 6.124, 'grad_norm': 3.4893124103546143, 'learning_rate': 2.8332463272699187e-05, 'epoch': 0.4}
# {'loss': 5.5835, 'grad_norm': 2.600374221801758, 'learning_rate': 2.211288551659851e-05, 'epoch': 0.8}
#  50% 63/126 [03:12<02:50,  2.70s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:07,  2.92it/s]
#  12% 3/25 [00:01<00:10,  2.04it/s]
#  16% 4/25 [00:02<00:11,  1.78it/s]
#  20% 5/25 [00:02<00:12,  1.65it/s]
#  24% 6/25 [00:03<00:11,  1.58it/s]
#  28% 7/25 [00:04<00:11,  1.54it/s]
#  32% 8/25 [00:04<00:11,  1.51it/s]
#  36% 9/25 [00:05<00:10,  1.48it/s]
#  40% 10/25 [00:06<00:10,  1.47it/s]
#  44% 11/25 [00:06<00:09,  1.54it/s]
#  48% 12/25 [00:07<00:08,  1.53it/s]
#  52% 13/25 [00:08<00:07,  1.50it/s]
#  56% 14/25 [00:08<00:06,  1.66it/s]
#  60% 15/25 [00:09<00:06,  1.60it/s]
#  64% 16/25 [00:09<00:05,  1.54it/s]
#  68% 17/25 [00:10<00:05,  1.52it/s]
#  72% 18/25 [00:11<00:04,  1.48it/s]
#  76% 19/25 [00:12<00:04,  1.47it/s]
#  80% 20/25 [00:12<00:03,  1.48it/s]
#  84% 21/25 [00:13<00:02,  1.48it/s]
#  88% 22/25 [00:14<00:02,  1.47it/s]
#  92% 23/25 [00:14<00:01,  1.47it/s]
#  96% 24/25 [00:15<00:00,  1.46it/s]
#
# {'eval_loss': 5.279499053955078, 'eval_runtime': 16.8988, 'eval_samples_per_second': 11.835, 'eval_steps_per_second': 1.479, 'epoch': 1.0}
#  50% 63/126 [03:29<02:50,  2.70s/it]
# 100% 25/25 [00:16<00:00,  1.46it/s]
# {'loss': 5.301, 'grad_norm': 2.6186306476593018, 'learning_rate': 1.2673467308927993e-05, 'epoch': 1.19}
# {'loss': 5.0832, 'grad_norm': 2.3641440868377686, 'learning_rate': 4.134528511420082e-06, 'epoch': 1.59}
# {'loss': 5.0143, 'grad_norm': 1.742398977279663, 'learning_rate': 8.253992843185464e-08, 'epoch': 1.99}
# 100% 126/126 [06:42<00:00,  2.58s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:08,  2.81it/s]
#  12% 3/25 [00:01<00:10,  2.07it/s]
#  16% 4/25 [00:02<00:11,  1.79it/s]
#  20% 5/25 [00:02<00:12,  1.66it/s]
#  24% 6/25 [00:03<00:11,  1.59it/s]
#  28% 7/25 [00:04<00:11,  1.54it/s]
#  32% 8/25 [00:04<00:11,  1.50it/s]
#  36% 9/25 [00:05<00:10,  1.48it/s]
#  40% 10/25 [00:06<00:10,  1.47it/s]
#  44% 11/25 [00:06<00:09,  1.55it/s]
#  48% 12/25 [00:07<00:08,  1.52it/s]
#  52% 13/25 [00:08<00:07,  1.51it/s]
#  56% 14/25 [00:08<00:06,  1.66it/s]
#  60% 15/25 [00:09<00:06,  1.61it/s]
#  64% 16/25 [00:09<00:05,  1.55it/s]
#  68% 17/25 [00:10<00:05,  1.53it/s]
#  72% 18/25 [00:11<00:04,  1.49it/s]
#  76% 19/25 [00:12<00:04,  1.47it/s]
#  80% 20/25 [00:12<00:03,  1.46it/s]
#  84% 21/25 [00:13<00:02,  1.46it/s]
#  88% 22/25 [00:14<00:02,  1.48it/s]
#  92% 23/25 [00:14<00:01,  1.47it/s]
#  96% 24/25 [00:15<00:00,  1.46it/s]
#
# {'eval_loss': 4.966891288757324, 'eval_runtime': 16.9147, 'eval_samples_per_second': 11.824, 'eval_steps_per_second': 1.478, 'epoch': 2.0}
# 100% 126/126 [06:59<00:00,  2.58s/it]
# 100% 25/25 [00:16<00:00,  1.46it/s]
# {'train_runtime': 420.247, 'train_samples_per_second': 4.759, 'train_steps_per_second': 0.3, 'train_loss': 5.417248090108235, 'epoch': 2.0}
# 100% 126/126 [07:00<00:00,  3.34s/it]
# [I 2026-03-17 02:39:50,030] Trial 1 finished with value: 4.966891288757324 and parameters: {'learning_rate': 2.963479251005086e-05}. Best is trial 1 with value: 4.966891288757324.
#
# --- CHECKING LORA RANK DISTRIBUTION (LORA LAYERS) ---
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.2.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.2.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.3.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.3.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.3.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.3.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.4.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.q            | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.v            | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.q            | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.v            | Rank: 16
# --------------------------------------------------
#
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# {'loss': 6.064, 'grad_norm': 6.191986560821533, 'learning_rate': 3.729049154794584e-05, 'epoch': 0.4}
# {'loss': 5.4129, 'grad_norm': 2.033604383468628, 'learning_rate': 2.8653013000020096e-05, 'epoch': 0.8}
#  50% 63/126 [03:12<02:48,  2.68s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:07,  2.90it/s]
#  12% 3/25 [00:01<00:10,  2.02it/s]
#  16% 4/25 [00:02<00:11,  1.78it/s]
#  20% 5/25 [00:02<00:12,  1.65it/s]
#  24% 6/25 [00:03<00:12,  1.58it/s]
#  28% 7/25 [00:04<00:11,  1.54it/s]
#  32% 8/25 [00:04<00:11,  1.51it/s]
#  36% 9/25 [00:05<00:10,  1.48it/s]
#  40% 10/25 [00:06<00:10,  1.47it/s]
#  44% 11/25 [00:06<00:09,  1.55it/s]
#  48% 12/25 [00:07<00:08,  1.52it/s]
#  52% 13/25 [00:08<00:07,  1.51it/s]
#  56% 14/25 [00:08<00:06,  1.65it/s]
#  60% 15/25 [00:09<00:06,  1.59it/s]
#  64% 16/25 [00:09<00:05,  1.55it/s]
#  68% 17/25 [00:10<00:05,  1.50it/s]
#  72% 18/25 [00:11<00:04,  1.51it/s]
#  76% 19/25 [00:12<00:04,  1.49it/s]
#  80% 20/25 [00:12<00:03,  1.48it/s]
#  84% 21/25 [00:13<00:02,  1.48it/s]
#  88% 22/25 [00:14<00:02,  1.47it/s]
#  92% 23/25 [00:14<00:01,  1.46it/s]
#  96% 24/25 [00:15<00:00,  1.46it/s]
# 100% 25/25 [00:16<00:00,  1.46it/s]
# {'eval_loss': 4.975025653839111, 'eval_runtime': 16.8638, 'eval_samples_per_second': 11.86, 'eval_steps_per_second': 1.482, 'epoch': 1.0}
#
#  50% 63/126 [03:28<02:48,  2.68s/it]
# {'loss': 5.0664, 'grad_norm': 2.0611259937286377, 'learning_rate': 1.617210704188007e-05, 'epoch': 1.19}
# {'loss': 4.8325, 'grad_norm': 1.6863197088241577, 'learning_rate': 5.089924471451562e-06, 'epoch': 1.59}
# {'loss': 4.7776, 'grad_norm': 1.815738558769226, 'learning_rate': 6.113317896426368e-08, 'epoch': 1.99}
# 100% 126/126 [06:41<00:00,  2.62s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:07,  2.99it/s]
#  12% 3/25 [00:01<00:10,  2.06it/s]
#  16% 4/25 [00:02<00:11,  1.78it/s]
#  20% 5/25 [00:02<00:12,  1.66it/s]
#  24% 6/25 [00:03<00:11,  1.59it/s]
#  28% 7/25 [00:04<00:11,  1.54it/s]
#  32% 8/25 [00:04<00:11,  1.51it/s]
#  36% 9/25 [00:05<00:10,  1.48it/s]
#  40% 10/25 [00:06<00:10,  1.47it/s]
#  44% 11/25 [00:06<00:09,  1.54it/s]
#  48% 12/25 [00:07<00:08,  1.52it/s]
#  52% 13/25 [00:08<00:07,  1.51it/s]
#  56% 14/25 [00:08<00:06,  1.65it/s]
#  60% 15/25 [00:09<00:06,  1.60it/s]
#  64% 16/25 [00:09<00:05,  1.56it/s]
#  68% 17/25 [00:10<00:05,  1.51it/s]
#  72% 18/25 [00:11<00:04,  1.49it/s]
#  76% 19/25 [00:12<00:04,  1.46it/s]
#  80% 20/25 [00:12<00:03,  1.46it/s]
#  84% 21/25 [00:13<00:02,  1.47it/s]
#  88% 22/25 [00:14<00:02,  1.47it/s]
#  92% 23/25 [00:14<00:01,  1.47it/s]
#  96% 24/25 [00:15<00:00,  1.45it/s]
# 100% 25/25 [00:16<00:00,  1.46it/s]
# {'eval_loss': 4.704549789428711, 'eval_runtime': 16.9481, 'eval_samples_per_second': 11.801, 'eval_steps_per_second': 1.475, 'epoch': 2.0}
#
# 100% 126/126 [06:58<00:00,  2.62s/it]
# {'train_runtime': 419.6112, 'train_samples_per_second': 4.766, 'train_steps_per_second': 0.3, 'train_loss': 5.226212107946003, 'epoch': 2.0}
# 100% 126/126 [06:59<00:00,  3.33s/it]
# [I 2026-03-17 02:46:53,744] Trial 2 finished with value: 4.704549789428711 and parameters: {'learning_rate': 3.9004585269719104e-05}. Best is trial 2 with value: 4.704549789428711.
#
# --- CHECKING LORA RANK DISTRIBUTION (LORA LAYERS) ---
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.v               | Rank: 4
# ...
# Layer: base_model.model.decoder.block.4.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.q            | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.v            | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.q            | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.v            | Rank: 16
# --------------------------------------------------
#
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# {'loss': 6.1403, 'grad_norm': 3.3024120330810547, 'learning_rate': 2.4130339725361454e-05, 'epoch': 0.4}
# {'loss': 5.6642, 'grad_norm': 2.43709135055542, 'learning_rate': 1.8833217383456702e-05, 'epoch': 0.8}
#  50% 63/126 [03:13<02:48,  2.67s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:07,  2.88it/s]
#  12% 3/25 [00:01<00:10,  2.03it/s]
#  16% 4/25 [00:02<00:11,  1.77it/s]
#  20% 5/25 [00:02<00:12,  1.65it/s]
#  24% 6/25 [00:03<00:12,  1.58it/s]
#  28% 7/25 [00:04<00:11,  1.54it/s]
#  32% 8/25 [00:04<00:11,  1.50it/s]
#  36% 9/25 [00:05<00:10,  1.48it/s]
#  40% 10/25 [00:06<00:10,  1.47it/s]
#  44% 11/25 [00:06<00:09,  1.54it/s]
#  48% 12/25 [00:07<00:08,  1.51it/s]
#  52% 13/25 [00:08<00:08,  1.50it/s]
#  56% 14/25 [00:08<00:06,  1.63it/s]
#  60% 15/25 [00:09<00:06,  1.57it/s]
#  64% 16/25 [00:10<00:05,  1.55it/s]
#  68% 17/25 [00:10<00:05,  1.53it/s]
#  72% 18/25 [00:11<00:04,  1.50it/s]
#  76% 19/25 [00:12<00:04,  1.49it/s]
#  80% 20/25 [00:12<00:03,  1.48it/s]
#  84% 21/25 [00:13<00:02,  1.48it/s]
#  88% 22/25 [00:14<00:02,  1.47it/s]
#  92% 23/25 [00:14<00:01,  1.47it/s]
#  96% 24/25 [00:15<00:00,  1.46it/s]
#
# {'eval_loss': 5.416152477264404, 'eval_runtime': 16.9, 'eval_samples_per_second': 11.834, 'eval_steps_per_second': 1.479, 'epoch': 1.0}
#  50% 63/126 [03:30<02:48,  2.67s/it]
# 100% 25/25 [00:16<00:00,  1.43it/s]
# {'loss': 5.4221, 'grad_norm': 3.260835886001587, 'learning_rate': 1.0793804573899315e-05, 'epoch': 1.19}
# {'loss': 5.2254, 'grad_norm': 2.6304943561553955, 'learning_rate': 3.5213167533122466e-06, 'epoch': 1.59}
# {'loss': 5.1556, 'grad_norm': 2.624008893966675, 'learning_rate': 7.02980356772179e-08, 'epoch': 1.99}
# 100% 126/126 [06:45<00:00,  2.59s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:07,  2.91it/s]
#  12% 3/25 [00:01<00:10,  2.04it/s]
#  16% 4/25 [00:02<00:11,  1.78it/s]
#  20% 5/25 [00:02<00:12,  1.65it/s]
#  24% 6/25 [00:03<00:11,  1.58it/s]
#  28% 7/25 [00:04<00:11,  1.54it/s]
#  32% 8/25 [00:04<00:11,  1.51it/s]
#  36% 9/25 [00:05<00:10,  1.48it/s]
#  40% 10/25 [00:06<00:10,  1.47it/s]
#  44% 11/25 [00:06<00:09,  1.53it/s]
#  48% 12/25 [00:07<00:08,  1.51it/s]
#  52% 13/25 [00:08<00:08,  1.49it/s]
#  56% 14/25 [00:08<00:06,  1.63it/s]
#  60% 15/25 [00:09<00:06,  1.59it/s]
#  64% 16/25 [00:10<00:05,  1.54it/s]
#  68% 17/25 [00:10<00:05,  1.53it/s]
#  72% 18/25 [00:11<00:04,  1.50it/s]
#  76% 19/25 [00:12<00:04,  1.49it/s]
#  80% 20/25 [00:12<00:03,  1.48it/s]
#  84% 21/25 [00:13<00:02,  1.47it/s]
#  88% 22/25 [00:14<00:02,  1.48it/s]
#  92% 23/25 [00:14<00:01,  1.47it/s]
#  96% 24/25 [00:15<00:00,  1.46it/s]
# 100% 25/25 [00:16<00:00,  1.46it/s]
# {'eval_loss': 5.139794826507568, 'eval_runtime': 16.8795, 'eval_samples_per_second': 11.849, 'eval_steps_per_second': 1.481, 'epoch': 2.0}
#
# 100% 126/126 [07:02<00:00,  2.59s/it]
# {'train_runtime': 423.3707, 'train_samples_per_second': 4.724, 'train_steps_per_second': 0.298, 'train_loss': 5.51797454319303, 'epoch': 2.0}
# 100% 126/126 [07:03<00:00,  3.36s/it]
# [I 2026-03-17 02:54:01,210] Trial 3 finished with value: 5.139794826507568 and parameters: {'learning_rate': 2.523951426585572e-05}. Best is trial 2 with value: 4.704549789428711.
#
# --- CHECKING LORA RANK DISTRIBUTION (LORA LAYERS) ---
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.2.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.2.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.3.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.3.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.3.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.3.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.4.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.q            | Rank: 16
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.v            | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.q              | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.v              | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.q            | Rank: 16
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.v            | Rank: 16
# --------------------------------------------------
#
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# {'loss': 6.07, 'grad_norm': 7.630369186401367, 'learning_rate': 3.617596224510068e-05, 'epoch': 0.4}
# {'loss': 5.4296, 'grad_norm': 2.0013041496276855, 'learning_rate': 2.7796638592558454e-05, 'epoch': 0.8}
#  50% 63/126 [03:11<02:46,  2.64s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:07,  2.89it/s]
#  12% 3/25 [00:01<00:10,  2.02it/s]
#  16% 4/25 [00:02<00:11,  1.77it/s]
#  20% 5/25 [00:02<00:12,  1.65it/s]
#  24% 6/25 [00:03<00:12,  1.57it/s]
#  28% 7/25 [00:04<00:11,  1.50it/s]
#  32% 8/25 [00:04<00:11,  1.50it/s]
#  36% 9/25 [00:05<00:10,  1.47it/s]
#  40% 10/25 [00:06<00:10,  1.44it/s]
#  44% 11/25 [00:06<00:09,  1.54it/s]
#  48% 12/25 [00:07<00:08,  1.52it/s]
#  52% 13/25 [00:08<00:07,  1.51it/s]
#  56% 14/25 [00:08<00:06,  1.65it/s]
#  60% 15/25 [00:09<00:06,  1.61it/s]
#  64% 16/25 [00:10<00:05,  1.56it/s]
#  68% 17/25 [00:10<00:05,  1.53it/s]
#  72% 18/25 [00:11<00:04,  1.51it/s]
#  76% 19/25 [00:12<00:04,  1.50it/s]
#  80% 20/25 [00:12<00:03,  1.49it/s]
#  84% 21/25 [00:13<00:02,  1.48it/s]
#  88% 22/25 [00:14<00:02,  1.47it/s]
#  92% 23/25 [00:14<00:01,  1.47it/s]
#  96% 24/25 [00:15<00:00,  1.46it/s]
# 100% 25/25 [00:16<00:00,  1.46it/s]
# {'eval_loss': 4.995358467102051, 'eval_runtime': 16.8727, 'eval_samples_per_second': 11.853, 'eval_steps_per_second': 1.482, 'epoch': 1.0}
#
#  50% 63/126 [03:28<02:46,  2.64s/it]
# {'loss': 5.0869, 'grad_norm': 2.0912771224975586, 'learning_rate': 1.568875897005996e-05, 'epoch': 1.19}
# {'loss': 4.8566, 'grad_norm': 1.6521544456481934, 'learning_rate': 4.937798024810129e-06, 'epoch': 1.59}
# {'loss': 4.8012, 'grad_norm': 1.796496868133545, 'learning_rate': 5.9306045115836255e-08, 'epoch': 1.99}
# 100% 126/126 [06:41<00:00,  2.59s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:07,  2.88it/s]
#  12% 3/25 [00:01<00:10,  2.02it/s]
#  16% 4/25 [00:02<00:11,  1.78it/s]
#  20% 5/25 [00:02<00:12,  1.66it/s]
#  24% 6/25 [00:03<00:12,  1.57it/s]
#  28% 7/25 [00:04<00:11,  1.54it/s]
#  32% 8/25 [00:04<00:11,  1.51it/s]
#  36% 9/25 [00:05<00:10,  1.47it/s]
#  40% 10/25 [00:06<00:10,  1.46it/s]
#  44% 11/25 [00:06<00:09,  1.52it/s]
#  48% 12/25 [00:07<00:08,  1.52it/s]
#  52% 13/25 [00:08<00:07,  1.51it/s]
#  56% 14/25 [00:08<00:06,  1.65it/s]
#  60% 15/25 [00:09<00:06,  1.60it/s]
#  64% 16/25 [00:10<00:05,  1.55it/s]
#  68% 17/25 [00:10<00:05,  1.53it/s]
#  72% 18/25 [00:11<00:04,  1.51it/s]
#  76% 19/25 [00:12<00:04,  1.49it/s]
#  80% 20/25 [00:12<00:03,  1.48it/s]
#  84% 21/25 [00:13<00:02,  1.48it/s]
#  88% 22/25 [00:14<00:02,  1.47it/s]
#  92% 23/25 [00:14<00:01,  1.47it/s]
#  96% 24/25 [00:15<00:00,  1.46it/s]
# 100% 25/25 [00:16<00:00,  1.46it/s]
# {'eval_loss': 4.732555389404297, 'eval_runtime': 16.8673, 'eval_samples_per_second': 11.857, 'eval_steps_per_second': 1.482, 'epoch': 2.0}
#
# 100% 126/126 [06:58<00:00,  2.59s/it]
# {'train_runtime': 419.4212, 'train_samples_per_second': 4.768, 'train_steps_per_second': 0.3, 'train_loss': 5.244518893105643, 'epoch': 2.0}
# 100% 126/126 [06:59<00:00,  3.33s/it]
# [I 2026-03-17 03:01:05,100] Trial 4 finished with value: 4.732555389404297 and parameters: {'learning_rate': 3.7838825543207294e-05}. Best is trial 2 with value: 4.704549789428711.
# ==================================================
# Hyperparameters searching completed!
# Best hp found: {'learning_rate': 3.9004585269719104e-05}
# Best eval_loss: 4.704549789428711
# ==================================================
# Thư mục 'customize_QLORA_hp_search_checkpoint' đã được nén thành công thành 'customize_QLORA_hp_search_checkpoint.zip'
# Bạn có thể tải tệp 'customize_QLORA_hp_search_checkpoint.zip' từ phần duyệt tệp của Colab (biểu tượng thư mục ở bên trái).
# === FINISH ===
