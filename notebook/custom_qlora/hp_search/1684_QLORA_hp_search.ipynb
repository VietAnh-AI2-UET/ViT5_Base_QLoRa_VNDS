# %%
# !git clone https://github.com/VietAnh-AI2-UET/ViT5_Base_QLoRa_VNDS.git
# Out:
# Cloning into 'ViT5_Base_QLoRa_VNDS'...
# remote: Enumerating objects: 227, done.
# remote: Counting objects: 100% (227/227), done.
# remote: Compressing objects: 100% (158/158), done.
# remote: Total 227 (delta 87), reused 180 (delta 42), pack-reused 0 (from 0)
# Receiving objects: 100% (227/227), 206.94 KiB | 1.21 MiB/s, done.
# Resolving deltas: 100% (87/87), done.

# %%
# %cd ViT5_Base_QLoRa_VNDS
# Out:
# /content/ViT5_Base_QLoRa_VNDS

# %%
# !git checkout customize
# Out:
# Branch 'customize' set up to track remote branch 'customize' from 'origin'.
# Switched to a new branch 'customize'

# %%
# !chmod +x runner/hp_search_runner.sh

# %%
# !./runner/hp_search_runner.sh
# Out:
# === SETTING UP HYPERPARAMS SEARCHING EXPERIMENT ===
# Installing gettext library for bash
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# gettext is already the newest version (0.21-4ubuntu4).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# Installing requirements.txt
# Creating configs file at: configs/hp_search_exp/hp_search_configs.yaml
# Start running scripts/custom_qlora/hp_search.py
# 2026-03-17 05:50:34.041832: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773726634.064604    7480 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773726634.071992    7480 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773726634.090453    7480 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773726634.090481    7480 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773726634.090485    7480 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773726634.090490    7480 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-17 05:50:34.095418: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ===== RUNNING CUSTOMIZE_RANK.PY =====
# Step 0: Loading configuration for VietAI/vit5-base fine-tuning completed
# STEP 1: LOADING TOKENIZER AND DATASET COMPLETED
# Map: 100% 200/200 [00:00<00:00, 487.94 examples/s]
# STEP 2: PREPROCESSING DATA COMPLETED
# STEP 3: SETTING UP VietAI/vit5-base QUANTIZATION COMPLETED
#
# --- CHECKING LORA RANK DISTRIBUTION (LORA LAYERS) ---
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.2.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.2.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.3.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.3.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.3.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.3.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.4.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.q            | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.v            | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.q            | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.v            | Rank: 4
# --------------------------------------------------
#
# STEP 4: SETTING UP HYPERPARAMS COMPLETED
# /content/ViT5_Base_QLoRa_VNDS/scripts/custom_qlora/hp_search.py:238: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(
#
# --- CHECKING LORA RANK DISTRIBUTION (LORA LAYERS) ---
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.2.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.2.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.3.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.3.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.3.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.3.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.4.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.q            | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.v            | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.q            | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.v            | Rank: 4
# --------------------------------------------------
#
# ===== START HYPERPARAMS SEARCHING VietAI/vit5-base =====
# [I 2026-03-17 05:50:53,133] A new study created in memory with name: no-name-08c1af62-bef7-4350-8e12-5f84e886f43a
#
# --- CHECKING LORA RANK DISTRIBUTION (LORA LAYERS) ---
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.2.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.2.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.3.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.3.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.3.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.3.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.4.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.q            | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.v            | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.q            | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.v            | Rank: 4
# --------------------------------------------------
#
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# {'loss': 5.162, 'grad_norm': 1.1842763423919678, 'learning_rate': 0.0004600514519489252, 'epoch': 0.4}
# {'loss': 3.7547, 'grad_norm': 1.0488178730010986, 'learning_rate': 0.00035709877303335486, 'epoch': 0.8}
#  50% 63/126 [03:18<02:53,  2.75s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:08,  2.86it/s]
#  12% 3/25 [00:01<00:10,  2.01it/s]
#  16% 4/25 [00:02<00:11,  1.76it/s]
#  20% 5/25 [00:02<00:12,  1.64it/s]
#  24% 6/25 [00:03<00:12,  1.57it/s]
#  28% 7/25 [00:04<00:11,  1.52it/s]
#  32% 8/25 [00:04<00:11,  1.49it/s]
#  36% 9/25 [00:05<00:10,  1.47it/s]
#  40% 10/25 [00:06<00:10,  1.44it/s]
#  44% 11/25 [00:06<00:09,  1.50it/s]
#  48% 12/25 [00:07<00:08,  1.49it/s]
#  52% 13/25 [00:08<00:08,  1.47it/s]
#  56% 14/25 [00:08<00:06,  1.64it/s]
#  60% 15/25 [00:09<00:06,  1.59it/s]
#  64% 16/25 [00:10<00:05,  1.54it/s]
#  68% 17/25 [00:10<00:05,  1.51it/s]
#  72% 18/25 [00:11<00:04,  1.49it/s]
#  76% 19/25 [00:12<00:04,  1.48it/s]
#  80% 20/25 [00:12<00:03,  1.47it/s]
#  84% 21/25 [00:13<00:02,  1.46it/s]
#  88% 22/25 [00:14<00:02,  1.46it/s]
#  92% 23/25 [00:14<00:01,  1.45it/s]
#  96% 24/25 [00:15<00:00,  1.45it/s]
#
# {'eval_loss': 3.427189826965332, 'eval_runtime': 17.0343, 'eval_samples_per_second': 11.741, 'eval_steps_per_second': 1.468, 'epoch': 1.0}
#  50% 63/126 [03:35<02:53,  2.75s/it]
# 100% 25/25 [00:16<00:00,  1.45it/s]
# {'loss': 3.5508, 'grad_norm': 1.0726398229599, 'learning_rate': 0.00020466255399818477, 'epoch': 1.19}
# {'loss': 3.4208, 'grad_norm': 1.4731342792510986, 'learning_rate': 6.676808675155868e-05, 'epoch': 1.59}
# {'loss': 3.4725, 'grad_norm': 0.9599804282188416, 'learning_rate': 1.332929035749386e-06, 'epoch': 1.99}
# 100% 126/126 [06:51<00:00,  2.60s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:08,  2.84it/s]
#  12% 3/25 [00:01<00:10,  2.01it/s]
#  16% 4/25 [00:02<00:11,  1.75it/s]
#  20% 5/25 [00:02<00:12,  1.63it/s]
#  24% 6/25 [00:03<00:12,  1.55it/s]
#  28% 7/25 [00:04<00:11,  1.50it/s]
#  32% 8/25 [00:04<00:11,  1.47it/s]
#  36% 9/25 [00:05<00:10,  1.45it/s]
#  40% 10/25 [00:06<00:10,  1.45it/s]
#  44% 11/25 [00:06<00:09,  1.51it/s]
#  48% 12/25 [00:07<00:08,  1.50it/s]
#  52% 13/25 [00:08<00:08,  1.49it/s]
#  56% 14/25 [00:08<00:06,  1.63it/s]
#  60% 15/25 [00:09<00:06,  1.58it/s]
#  64% 16/25 [00:10<00:05,  1.53it/s]
#  68% 17/25 [00:10<00:05,  1.51it/s]
#  72% 18/25 [00:11<00:04,  1.48it/s]
#  76% 19/25 [00:12<00:04,  1.47it/s]
#  80% 20/25 [00:12<00:03,  1.45it/s]
#  84% 21/25 [00:13<00:02,  1.46it/s]
#  88% 22/25 [00:14<00:02,  1.45it/s]
#  92% 23/25 [00:15<00:01,  1.44it/s]
#  96% 24/25 [00:15<00:00,  1.43it/s]
#
# {'eval_loss': 3.34940767288208, 'eval_runtime': 17.1204, 'eval_samples_per_second': 11.682, 'eval_steps_per_second': 1.46, 'epoch': 2.0}
# 100% 126/126 [07:08<00:00,  2.60s/it]
# 100% 25/25 [00:16<00:00,  1.43it/s]
# {'train_runtime': 428.7921, 'train_samples_per_second': 4.664, 'train_steps_per_second': 0.294, 'train_loss': 3.8676085850549122, 'epoch': 2.0}
# 100% 126/126 [07:08<00:00,  3.40s/it]
# [I 2026-03-17 05:58:05,685] Trial 0 finished with value: 3.34940767288208 and parameters: {'learning_rate': 0.00047856929555817947}. Best is trial 0 with value: 3.34940767288208.
#
# --- CHECKING LORA RANK DISTRIBUTION (LORA LAYERS) ---
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.2.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.2.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.3.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.3.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.3.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.3.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.4.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.q            | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.v            | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.q            | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.v            | Rank: 4
# --------------------------------------------------
#
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# {'loss': 6.1045, 'grad_norm': 13.901905059814453, 'learning_rate': 3.028840053288195e-05, 'epoch': 0.4}
# {'loss': 5.5047, 'grad_norm': 2.783033847808838, 'learning_rate': 2.3272794167989136e-05, 'epoch': 0.8}
#  50% 63/126 [03:13<02:48,  2.68s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:07,  2.88it/s]
#  12% 3/25 [00:01<00:10,  2.02it/s]
#  16% 4/25 [00:02<00:11,  1.75it/s]
#  20% 5/25 [00:02<00:12,  1.62it/s]
#  24% 6/25 [00:03<00:12,  1.55it/s]
#  28% 7/25 [00:04<00:11,  1.51it/s]
#  32% 8/25 [00:04<00:11,  1.48it/s]
#  36% 9/25 [00:05<00:10,  1.46it/s]
#  40% 10/25 [00:06<00:10,  1.44it/s]
#  44% 11/25 [00:06<00:09,  1.51it/s]
#  48% 12/25 [00:07<00:08,  1.50it/s]
#  52% 13/25 [00:08<00:08,  1.49it/s]
#  56% 14/25 [00:08<00:06,  1.62it/s]
#  60% 15/25 [00:09<00:06,  1.57it/s]
#  64% 16/25 [00:10<00:05,  1.53it/s]
#  68% 17/25 [00:10<00:05,  1.49it/s]
#  72% 18/25 [00:11<00:04,  1.46it/s]
#  76% 19/25 [00:12<00:04,  1.45it/s]
#  80% 20/25 [00:12<00:03,  1.44it/s]
#  84% 21/25 [00:13<00:02,  1.45it/s]
#  88% 22/25 [00:14<00:02,  1.45it/s]
#  92% 23/25 [00:15<00:01,  1.44it/s]
#  96% 24/25 [00:15<00:00,  1.44it/s]
# 100% 25/25 [00:16<00:00,  1.44it/s]
# {'eval_loss': 5.280778408050537, 'eval_runtime': 17.2027, 'eval_samples_per_second': 11.626, 'eval_steps_per_second': 1.453, 'epoch': 1.0}
#
#  50% 63/126 [03:30<02:48,  2.68s/it]
# {'loss': 5.2689, 'grad_norm': 2.5115716457366943, 'learning_rate': 1.3135446469385212e-05, 'epoch': 1.19}
# {'loss': 5.1258, 'grad_norm': 2.042238473892212, 'learning_rate': 4.134181789350391e-06, 'epoch': 1.59}
# {'loss': 5.0816, 'grad_norm': 1.9548410177230835, 'learning_rate': 4.965411110060761e-08, 'epoch': 1.99}
# 100% 126/126 [06:45<00:00,  2.60s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:07,  2.91it/s]
#  12% 3/25 [00:01<00:10,  2.02it/s]
#  16% 4/25 [00:02<00:11,  1.76it/s]
#  20% 5/25 [00:02<00:12,  1.63it/s]
#  24% 6/25 [00:03<00:12,  1.56it/s]
#  28% 7/25 [00:04<00:11,  1.52it/s]
#  32% 8/25 [00:04<00:11,  1.49it/s]
#  36% 9/25 [00:05<00:10,  1.46it/s]
#  40% 10/25 [00:06<00:10,  1.45it/s]
#  44% 11/25 [00:06<00:09,  1.53it/s]
#  48% 12/25 [00:07<00:08,  1.51it/s]
#  52% 13/25 [00:08<00:08,  1.49it/s]
#  56% 14/25 [00:08<00:06,  1.64it/s]
#  60% 15/25 [00:09<00:06,  1.58it/s]
#  64% 16/25 [00:10<00:05,  1.54it/s]
#  68% 17/25 [00:10<00:05,  1.49it/s]
#  72% 18/25 [00:11<00:04,  1.46it/s]
#  76% 19/25 [00:12<00:04,  1.46it/s]
#  80% 20/25 [00:12<00:03,  1.44it/s]
#  84% 21/25 [00:13<00:02,  1.45it/s]
#  88% 22/25 [00:14<00:02,  1.45it/s]
#  92% 23/25 [00:14<00:01,  1.45it/s]
#  96% 24/25 [00:15<00:00,  1.44it/s]
# 100% 25/25 [00:16<00:00,  1.44it/s]
# {'eval_loss': 5.112245082855225, 'eval_runtime': 17.1464, 'eval_samples_per_second': 11.664, 'eval_steps_per_second': 1.458, 'epoch': 2.0}
#
# 100% 126/126 [07:02<00:00,  2.60s/it]
# {'train_runtime': 423.0483, 'train_samples_per_second': 4.728, 'train_steps_per_second': 0.298, 'train_loss': 5.413581174517435, 'epoch': 2.0}
# 100% 126/126 [07:03<00:00,  3.36s/it]
# [I 2026-03-17 06:05:12,405] Trial 1 finished with value: 5.112245082855225 and parameters: {'learning_rate': 3.1680636329216656e-05}. Best is trial 0 with value: 3.34940767288208.
#
# --- CHECKING LORA RANK DISTRIBUTION (LORA LAYERS) ---
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.2.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.2.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.3.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.3.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.3.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.3.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.4.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.q            | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.v            | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.q            | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.v            | Rank: 4
# --------------------------------------------------
#
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# {'loss': 5.4317, 'grad_norm': 2.028970956802368, 'learning_rate': 0.0002441803428780115, 'epoch': 0.4}
# {'loss': 4.0586, 'grad_norm': 2.368875741958618, 'learning_rate': 0.00018762162278921295, 'epoch': 0.8}
#  50% 63/126 [03:13<02:50,  2.71s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:08,  2.84it/s]
#  12% 3/25 [00:01<00:11,  2.00it/s]
#  16% 4/25 [00:02<00:11,  1.75it/s]
#  20% 5/25 [00:02<00:12,  1.63it/s]
#  24% 6/25 [00:03<00:12,  1.56it/s]
#  28% 7/25 [00:04<00:11,  1.51it/s]
#  32% 8/25 [00:04<00:11,  1.48it/s]
#  36% 9/25 [00:05<00:10,  1.46it/s]
#  40% 10/25 [00:06<00:10,  1.45it/s]
#  44% 11/25 [00:06<00:09,  1.52it/s]
#  48% 12/25 [00:07<00:08,  1.49it/s]
#  52% 13/25 [00:08<00:08,  1.47it/s]
#  56% 14/25 [00:08<00:06,  1.61it/s]
#  60% 15/25 [00:09<00:06,  1.56it/s]
#  64% 16/25 [00:10<00:05,  1.50it/s]
#  68% 17/25 [00:10<00:05,  1.50it/s]
#  72% 18/25 [00:11<00:04,  1.48it/s]
#  76% 19/25 [00:12<00:04,  1.47it/s]
#  80% 20/25 [00:12<00:03,  1.46it/s]
#  84% 21/25 [00:13<00:02,  1.45it/s]
#  88% 22/25 [00:14<00:02,  1.45it/s]
#  92% 23/25 [00:15<00:01,  1.44it/s]
#  96% 24/25 [00:15<00:00,  1.44it/s]
#
# {'eval_loss': 3.642069101333618, 'eval_runtime': 17.1568, 'eval_samples_per_second': 11.657, 'eval_steps_per_second': 1.457, 'epoch': 1.0}
#  50% 63/126 [03:30<02:50,  2.71s/it]
# 100% 25/25 [00:16<00:00,  1.44it/s]
# {'loss': 3.7768, 'grad_norm': 1.2398560047149658, 'learning_rate': 0.00010589591283528435, 'epoch': 1.19}
# {'loss': 3.6029, 'grad_norm': 1.0130681991577148, 'learning_rate': 3.332912630192152e-05, 'epoch': 1.59}
# {'loss': 3.6317, 'grad_norm': 1.056481122970581, 'learning_rate': 4.00303669409234e-07, 'epoch': 1.99}
# 100% 126/126 [06:45<00:00,  2.63s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:08,  2.87it/s]
#  12% 3/25 [00:01<00:10,  2.01it/s]
#  16% 4/25 [00:02<00:12,  1.74it/s]
#  20% 5/25 [00:02<00:12,  1.63it/s]
#  24% 6/25 [00:03<00:12,  1.56it/s]
#  28% 7/25 [00:04<00:11,  1.51it/s]
#  32% 8/25 [00:04<00:11,  1.48it/s]
#  36% 9/25 [00:05<00:10,  1.46it/s]
#  40% 10/25 [00:06<00:10,  1.45it/s]
#  44% 11/25 [00:06<00:09,  1.52it/s]
#  48% 12/25 [00:07<00:08,  1.50it/s]
#  52% 13/25 [00:08<00:08,  1.47it/s]
#  56% 14/25 [00:08<00:06,  1.62it/s]
#  60% 15/25 [00:09<00:06,  1.55it/s]
#  64% 16/25 [00:10<00:05,  1.50it/s]
#  68% 17/25 [00:10<00:05,  1.50it/s]
#  72% 18/25 [00:11<00:04,  1.48it/s]
#  76% 19/25 [00:12<00:04,  1.47it/s]
#  80% 20/25 [00:12<00:03,  1.46it/s]
#  84% 21/25 [00:13<00:02,  1.45it/s]
#  88% 22/25 [00:14<00:02,  1.45it/s]
#  92% 23/25 [00:15<00:01,  1.44it/s]
#  96% 24/25 [00:15<00:00,  1.43it/s]
#
# {'eval_loss': 3.4851675033569336, 'eval_runtime': 17.1586, 'eval_samples_per_second': 11.656, 'eval_steps_per_second': 1.457, 'epoch': 2.0}
# 100% 126/126 [07:02<00:00,  2.63s/it]
# 100% 25/25 [00:16<00:00,  1.44it/s]
# {'train_runtime': 423.3577, 'train_samples_per_second': 4.724, 'train_steps_per_second': 0.298, 'train_loss': 4.095561578160241, 'epoch': 2.0}
# 100% 126/126 [07:03<00:00,  3.36s/it]
# [I 2026-03-17 06:12:19,122] Trial 2 finished with value: 3.4851675033569336 and parameters: {'learning_rate': 0.0002554043298873943}. Best is trial 0 with value: 3.34940767288208.
#
# --- CHECKING LORA RANK DISTRIBUTION (LORA LAYERS) ---
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.v               | Rank: 16
# ...
# Layer: base_model.model.decoder.block.4.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.q            | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.v            | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.q            | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.v            | Rank: 4
# --------------------------------------------------
#
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# {'loss': 5.9107, 'grad_norm': 6.522461414337158, 'learning_rate': 6.723462468370507e-05, 'epoch': 0.4}
# {'loss': 5.0406, 'grad_norm': 1.8472648859024048, 'learning_rate': 5.166128133861497e-05, 'epoch': 0.8}
#  50% 63/126 [03:13<02:49,  2.68s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:08,  2.84it/s]
#  12% 3/25 [00:01<00:10,  2.01it/s]
#  16% 4/25 [00:02<00:12,  1.75it/s]
#  20% 5/25 [00:02<00:12,  1.63it/s]
#  24% 6/25 [00:03<00:12,  1.56it/s]
#  28% 7/25 [00:04<00:11,  1.51it/s]
#  32% 8/25 [00:04<00:11,  1.48it/s]
#  36% 9/25 [00:05<00:11,  1.45it/s]
#  40% 10/25 [00:06<00:10,  1.44it/s]
#  44% 11/25 [00:06<00:09,  1.49it/s]
#  48% 12/25 [00:07<00:08,  1.49it/s]
#  52% 13/25 [00:08<00:08,  1.48it/s]
#  56% 14/25 [00:08<00:06,  1.62it/s]
#  60% 15/25 [00:09<00:06,  1.58it/s]
#  64% 16/25 [00:10<00:05,  1.54it/s]
#  68% 17/25 [00:10<00:05,  1.51it/s]
#  72% 18/25 [00:11<00:04,  1.49it/s]
#  76% 19/25 [00:12<00:04,  1.47it/s]
#  80% 20/25 [00:12<00:03,  1.46it/s]
#  84% 21/25 [00:13<00:02,  1.45it/s]
#  88% 22/25 [00:14<00:02,  1.45it/s]
#  92% 23/25 [00:15<00:01,  1.45it/s]
#  96% 24/25 [00:15<00:00,  1.44it/s]
# 100% 25/25 [00:16<00:00,  1.44it/s]
# {'eval_loss': 4.60188102722168, 'eval_runtime': 17.1162, 'eval_samples_per_second': 11.685, 'eval_steps_per_second': 1.461, 'epoch': 1.0}
#
#  50% 63/126 [03:30<02:49,  2.68s/it]
# {'loss': 4.6965, 'grad_norm': 1.6867625713348389, 'learning_rate': 2.9158251934209386e-05, 'epoch': 1.19}
# {'loss': 4.4286, 'grad_norm': 2.1512811183929443, 'learning_rate': 9.177115862536894e-06, 'epoch': 1.59}
# {'loss': 4.3892, 'grad_norm': 1.9717905521392822, 'learning_rate': 1.1022290596784742e-07, 'epoch': 1.99}
# 100% 126/126 [06:45<00:00,  2.61s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:07,  2.88it/s]
#  12% 3/25 [00:01<00:10,  2.02it/s]
#  16% 4/25 [00:02<00:11,  1.75it/s]
#  20% 5/25 [00:02<00:12,  1.63it/s]
#  24% 6/25 [00:03<00:12,  1.56it/s]
#  28% 7/25 [00:04<00:11,  1.51it/s]
#  32% 8/25 [00:04<00:11,  1.48it/s]
#  36% 9/25 [00:05<00:11,  1.45it/s]
#  40% 10/25 [00:06<00:10,  1.42it/s]
#  44% 11/25 [00:06<00:09,  1.49it/s]
#  48% 12/25 [00:07<00:08,  1.50it/s]
#  52% 13/25 [00:08<00:08,  1.48it/s]
#  56% 14/25 [00:08<00:06,  1.62it/s]
#  60% 15/25 [00:09<00:06,  1.58it/s]
#  64% 16/25 [00:10<00:05,  1.54it/s]
#  68% 17/25 [00:10<00:05,  1.51it/s]
#  72% 18/25 [00:11<00:04,  1.49it/s]
#  76% 19/25 [00:12<00:04,  1.47it/s]
#  80% 20/25 [00:12<00:03,  1.46it/s]
#  84% 21/25 [00:13<00:02,  1.46it/s]
#  88% 22/25 [00:14<00:02,  1.45it/s]
#  92% 23/25 [00:15<00:01,  1.45it/s]
#  96% 24/25 [00:15<00:00,  1.44it/s]
# 100% 25/25 [00:16<00:00,  1.44it/s]
# {'eval_loss': 4.236785888671875, 'eval_runtime': 17.12, 'eval_samples_per_second': 11.682, 'eval_steps_per_second': 1.46, 'epoch': 2.0}
#
# 100% 126/126 [07:02<00:00,  2.61s/it]
# {'train_runtime': 423.1627, 'train_samples_per_second': 4.726, 'train_steps_per_second': 0.298, 'train_loss': 4.888259267050122, 'epoch': 2.0}
# 100% 126/126 [07:03<00:00,  3.36s/it]
# [I 2026-03-17 06:19:25,814] Trial 3 finished with value: 4.236785888671875 and parameters: {'learning_rate': 7.032512961598638e-05}. Best is trial 0 with value: 3.34940767288208.
#
# --- CHECKING LORA RANK DISTRIBUTION (LORA LAYERS) ---
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.0.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.1.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.2.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.encoder.block.3.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.4.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.encoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.8.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.encoder.block.9.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.encoder.block.10.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.encoder.block.11.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.0.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.1.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.2.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.2.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.2.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.3.layer.0.SelfAttention.q               | Rank: 16
# Layer: base_model.model.decoder.block.3.layer.0.SelfAttention.v               | Rank: 16
# Layer: base_model.model.decoder.block.3.layer.1.EncDecAttention.q             | Rank: 16
# Layer: base_model.model.decoder.block.3.layer.1.EncDecAttention.v             | Rank: 16
# Layer: base_model.model.decoder.block.4.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.4.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.5.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.6.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.q               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.0.SelfAttention.v               | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.q             | Rank: 8
# Layer: base_model.model.decoder.block.7.layer.1.EncDecAttention.v             | Rank: 8
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.8.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.8.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.q               | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.0.SelfAttention.v               | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.q             | Rank: 4
# Layer: base_model.model.decoder.block.9.layer.1.EncDecAttention.v             | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.q            | Rank: 4
# Layer: base_model.model.decoder.block.10.layer.1.EncDecAttention.v            | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.q              | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.0.SelfAttention.v              | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.q            | Rank: 4
# Layer: base_model.model.decoder.block.11.layer.1.EncDecAttention.v            | Rank: 4
# --------------------------------------------------
#
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# {'loss': 5.7197, 'grad_norm': 1.6102207899093628, 'learning_rate': 0.00011545679257577789, 'epoch': 0.4}
# {'loss': 4.647, 'grad_norm': 1.8202825784683228, 'learning_rate': 8.871390108550663e-05, 'epoch': 0.8}
#  50% 63/126 [03:13<02:47,  2.66s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:08,  2.85it/s]
#  12% 3/25 [00:01<00:11,  1.97it/s]
#  16% 4/25 [00:02<00:12,  1.72it/s]
#  20% 5/25 [00:02<00:12,  1.61it/s]
#  24% 6/25 [00:03<00:12,  1.53it/s]
#  28% 7/25 [00:04<00:11,  1.51it/s]
#  32% 8/25 [00:04<00:11,  1.48it/s]
#  36% 9/25 [00:05<00:10,  1.46it/s]
#  40% 10/25 [00:06<00:10,  1.45it/s]
#  44% 11/25 [00:06<00:09,  1.52it/s]
#  48% 12/25 [00:07<00:08,  1.50it/s]
#  52% 13/25 [00:08<00:08,  1.49it/s]
#  56% 14/25 [00:08<00:06,  1.63it/s]
#  60% 15/25 [00:09<00:06,  1.58it/s]
#  64% 16/25 [00:10<00:05,  1.52it/s]
#  68% 17/25 [00:10<00:05,  1.51it/s]
#  72% 18/25 [00:11<00:04,  1.49it/s]
#  76% 19/25 [00:12<00:04,  1.47it/s]
#  80% 20/25 [00:12<00:03,  1.47it/s]
#  84% 21/25 [00:13<00:02,  1.46it/s]
#  88% 22/25 [00:14<00:02,  1.43it/s]
#  92% 23/25 [00:15<00:01,  1.43it/s]
#  96% 24/25 [00:15<00:00,  1.42it/s]
# 100% 25/25 [00:16<00:00,  1.43it/s]
# {'eval_loss': 3.995776414871216, 'eval_runtime': 17.1264, 'eval_samples_per_second': 11.678, 'eval_steps_per_second': 1.46, 'epoch': 1.0}
#
#  50% 63/126 [03:30<02:47,  2.66s/it]
# {'loss': 4.168, 'grad_norm': 1.1545003652572632, 'learning_rate': 5.0071198601577e-05, 'epoch': 1.19}
# {'loss': 3.9564, 'grad_norm': 1.2023558616638184, 'learning_rate': 1.5759147426929825e-05, 'epoch': 1.59}
# {'loss': 3.9776, 'grad_norm': 1.052935242652893, 'learning_rate': 1.892772251097802e-07, 'epoch': 1.99}
# 100% 126/126 [06:45<00:00,  2.60s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:07,  2.90it/s]
#  12% 3/25 [00:01<00:10,  2.02it/s]
#  16% 4/25 [00:02<00:12,  1.73it/s]
#  20% 5/25 [00:02<00:12,  1.62it/s]
#  24% 6/25 [00:03<00:12,  1.54it/s]
#  28% 7/25 [00:04<00:11,  1.50it/s]
#  32% 8/25 [00:04<00:11,  1.48it/s]
#  36% 9/25 [00:05<00:10,  1.46it/s]
#  40% 10/25 [00:06<00:10,  1.45it/s]
#  44% 11/25 [00:06<00:09,  1.52it/s]
#  48% 12/25 [00:07<00:08,  1.50it/s]
#  52% 13/25 [00:08<00:08,  1.49it/s]
#  56% 14/25 [00:08<00:06,  1.63it/s]
#  60% 15/25 [00:09<00:06,  1.57it/s]
#  64% 16/25 [00:10<00:05,  1.54it/s]
#  68% 17/25 [00:10<00:05,  1.51it/s]
#  72% 18/25 [00:11<00:04,  1.49it/s]
#  76% 19/25 [00:12<00:04,  1.47it/s]
#  80% 20/25 [00:12<00:03,  1.46it/s]
#  84% 21/25 [00:13<00:02,  1.46it/s]
#  88% 22/25 [00:14<00:02,  1.44it/s]
#  92% 23/25 [00:15<00:01,  1.43it/s]
#  96% 24/25 [00:15<00:00,  1.43it/s]
# 100% 25/25 [00:16<00:00,  1.42it/s]
# {'eval_loss': 3.8343873023986816, 'eval_runtime': 17.13, 'eval_samples_per_second': 11.675, 'eval_steps_per_second': 1.459, 'epoch': 2.0}
#
# 100% 126/126 [07:02<00:00,  2.60s/it]
# {'train_runtime': 422.5631, 'train_samples_per_second': 4.733, 'train_steps_per_second': 0.298, 'train_loss': 4.488544653332423, 'epoch': 2.0}
# 100% 126/126 [07:02<00:00,  3.35s/it]
# [I 2026-03-17 06:26:32,358] Trial 4 finished with value: 3.8343873023986816 and parameters: {'learning_rate': 0.0001207638763677887}. Best is trial 0 with value: 3.34940767288208.
# ==================================================
# Hyperparameters searching completed!
# Best hp found: {'learning_rate': 0.00047856929555817947}
# Best eval_loss: 3.34940767288208
# ==================================================
# Thư mục '168a4_QLORA_hp_search_checkpoint' đã được nén thành công thành '168a4_QLORA_hp_search_checkpoint.zip'
# Bạn có thể tải tệp '168a4_QLORA_hp_search_checkpoint.zip' từ phần duyệt tệp của Colab (biểu tượng thư mục ở bên trái).
# === FINISH ===
