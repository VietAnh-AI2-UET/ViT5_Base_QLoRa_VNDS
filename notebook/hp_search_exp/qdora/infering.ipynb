# %%
# !git clone https://github.com/VietAnh-AI2-UET/ViT5_Base_QLoRa_VNDS.git
# Out:
# Cloning into 'ViT5_Base_QLoRa_VNDS'...
# remote: Enumerating objects: 170, done.
# remote: Counting objects: 100% (170/170), done.
# remote: Compressing objects: 100% (116/116), done.
# remote: Total 170 (delta 65), reused 135 (delta 32), pack-reused 0 (from 0)
# Receiving objects: 100% (170/170), 138.28 KiB | 1.18 MiB/s, done.
# Resolving deltas: 100% (65/65), done.

# %%
# %cd ViT5_Base_QLoRa_VNDS
# Out:
# /content/ViT5_Base_QLoRa_VNDS

# %%
# !git checkout hp_search
# Out:
# Branch 'hp_search' set up to track remote branch 'hp_search' from 'origin'.
# Switched to a new branch 'hp_search'

# %%
zip_path = "qdora_vit5_adapter.zip"
destination_path = "qdora_vit5_adapter"
# !unzip $zip_path -d $destination_path
# Out:
# Archive:  qdora_vit5_adapter.zip
#   inflating: qdora_vit5_adapter/README.md
#   inflating: qdora_vit5_adapter/tokenizer.json
#   inflating: qdora_vit5_adapter/training_args.bin
#   inflating: qdora_vit5_adapter/adapter_config.json
#   inflating: qdora_vit5_adapter/tokenizer_config.json
#   inflating: qdora_vit5_adapter/spiece.model
#   inflating: qdora_vit5_adapter/special_tokens_map.json
#   inflating: qdora_vit5_adapter/adapter_model.safetensors

# %%
# !chmod +x infer_runner.sh

# %%
# !./infer_runner.sh
# Out:
# === SETTING UP INFERENCING ===
# Installing gettext library for bash
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# gettext is already the newest version (0.21-4ubuntu4).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# Installing requirements.txt
# Creating configs file at: configs/baseline/inferencing_configs.yaml
# Start running scripts/baseline/inference.py
# 2026-03-12 04:55:54.959920: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773291354.980701    2444 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...
