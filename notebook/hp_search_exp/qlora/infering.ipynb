# %%
# !git clone https://github.com/VietAnh-AI2-UET/ViT5_Base_QLoRa_VNDS.git
# Out:
# Cloning into 'ViT5_Base_QLoRa_VNDS'...
# remote: Enumerating objects: 206, done.
# remote: Counting objects: 100% (206/206), done.
# remote: Compressing objects: 100% (139/139), done.
# Receiving objects: 100% (206/206), 199.52 KiB | 6.65 MiB/s, done.
# remote: Total 206 (delta 79), reused 166 (delta 41), pack-reused 0 (from 0)
# Resolving deltas: 100% (79/79), done.

# %%
# %cd ViT5_Base_QLoRa_VNDS
# Out:
# /content/ViT5_Base_QLoRa_VNDS

# %%
# !git checkout hp_search
# Out:
# Branch 'hp_search' set up to track remote branch 'hp_search' from 'origin'.
# Switched to a new branch 'hp_search'

# %%
zip_path = "./QLORA_optimLR_adapter.zip"
destination_path = "./QLORA_optimLR_adapter"
# !unzip $zip_path -d $destination_path
# Out:
# Archive:  ./QLORA_optimLR_adapter.zip
#   inflating: ./QLORA_optimLR_adapter/tokenizer.json
#   inflating: ./QLORA_optimLR_adapter/adapter_model.safetensors
#   inflating: ./QLORA_optimLR_adapter/spiece.model
#   inflating: ./QLORA_optimLR_adapter/tokenizer_config.json
#   inflating: ./QLORA_optimLR_adapter/adapter_config.json
#   inflating: ./QLORA_optimLR_adapter/training_args.bin
#   inflating: ./QLORA_optimLR_adapter/README.md
#   inflating: ./QLORA_optimLR_adapter/special_tokens_map.json

# %%
# !chmod +x runner/infer_runner.sh

# %%
# !./runner/infer_runner.sh
# Out:
# === SETTING UP INFERENCING ===
# Installing gettext library for bash
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   gettext-base
# Suggested packages:
#   gettext-doc autopoint libasprintf-dev libgettextpo-dev
# The following NEW packages will be installed:
#   gettext gettext-base
# 0 upgraded, 2 newly installed, 0 to remove and 37 not upgraded.
# Need to get 906 kB of archives.
# After this operation, 2,990 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 gettext-base amd64 0.21-4ubuntu4 [37.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 gettext amd64 0.21-4ubuntu4 [868 kB]
# Fetched 906 kB in 2s (545 kB/s)
# Selecting previously unselected package gettext-base.
# (Reading database ... 121852 files and directories currently installed.)
# Preparing to unpack .../gettext-base_0.21-4ubuntu4_amd64.deb ...
# ...
