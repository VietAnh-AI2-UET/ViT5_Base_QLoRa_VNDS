# %%
# !git clone https://github.com/VietAnh-AI2-UET/ViT5_Base_QLoRa_VNDS.git
# Out:
# Cloning into 'ViT5_Base_QLoRa_VNDS'...
# remote: Enumerating objects: 183, done.
# remote: Counting objects: 100% (183/183), done.
# remote: Compressing objects: 100% (124/124), done.
# remote: Total 183 (delta 70), reused 146 (delta 35), pack-reused 0 (from 0)
# Receiving objects: 100% (183/183), 142.81 KiB | 6.49 MiB/s, done.
# Resolving deltas: 100% (70/70), done.

# %%
# %cd ViT5_Base_QLoRa_VNDS
# Out:
# /content/ViT5_Base_QLoRa_VNDS

# %%
# !git checkout hp_search
# Out:
# Branch 'hp_search' set up to track remote branch 'hp_search' from 'origin'.
# Switched to a new branch 'hp_search'

# %%
# !chmod +x hp_search_runner.sh

# %%
# !./hp_search_runner.sh
# Out:
# === SETTING UP HYPERPARAMS SEARCHING EXPERIMENT ===
# Installing gettext library for bash
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   gettext-base
# Suggested packages:
#   gettext-doc autopoint libasprintf-dev libgettextpo-dev
# The following NEW packages will be installed:
#   gettext gettext-base
# 0 upgraded, 2 newly installed, 0 to remove and 37 not upgraded.
# Need to get 906 kB of archives.
# After this operation, 2,990 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 gettext-base amd64 0.21-4ubuntu4 [37.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 gettext amd64 0.21-4ubuntu4 [868 kB]
# Fetched 906 kB in 1s (1,276 kB/s)
# Selecting previously unselected package gettext-base.
# (Reading database ... 121852 files and directories currently installed.)
# Preparing to unpack .../gettext-base_0.21-4ubuntu4_amd64.deb ...
# Unpacking gettext-base (0.21-4ubuntu4) ...
# Selecting previously unselected package gettext.
# Preparing to unpack .../gettext_0.21-4ubuntu4_amd64.deb ...
# Unpacking gettext (0.21-4ubuntu4) ...
# Setting up gettext-base (0.21-4ubuntu4) ...
# Setting up gettext (0.21-4ubuntu4) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# Installing requirements.txt
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 9.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.1/75.1 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 14.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.9/380.9 kB 24.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 7.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 11.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.5/153.5 kB 17.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.2/515.2 kB 51.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 15.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 93.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.0/201.0 kB 24.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 52.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 77.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 102.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.3/150.3 kB 19.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 92.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 78.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.9/413.9 kB 41.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 127.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 103.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 kB 19.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.7/803.7 kB 41.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 75.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 17.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.3/377.3 kB 39.5 MB/s eta 0:00:00
#   Building wheel for rouge_score (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.1 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# dask-cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.
# bqplot 0.12.45 requires pandas<3.0.0,>=1.0.0, but you have pandas 3.0.1 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.4.2 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.4.2 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.10.0 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.1 which is incompatible.
# gradio 5.50.0 requires pillow<12.0,>=8.0, but you have pillow 12.1.1 which is incompatible.
# db-dtypes 1.5.0 requires pandas<3.0.0,>=1.5.3, but you have pandas 3.0.1 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.
# Creating configs file at: configs/hp_search_exp/hp_search_configs.yaml
# Start running scripts/hp_search/hp_search.py
# 2026-03-13 03:39:13.358235: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1773373153.388511    7810 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1773373153.397174    7810 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1773373153.415243    7810 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773373153.415267    7810 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773373153.415271    7810 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1773373153.415274    7810 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-13 03:39:13.419885: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Start running hp_search.py with Optuna Integration
# Step 0: Loading configuration for VietAI/vit5-base completed
# tokenizer_config.json: 2.20kB [00:00, 9.65MB/s]
# spiece.model: 100% 820k/820k [00:00<00:00, 1.00MB/s]
# tokenizer.json: 2.40MB [00:00, 73.1MB/s]
# special_tokens_map.json: 2.12kB [00:00, 13.3MB/s]
# README.md: 100% 748/748 [00:00<00:00, 5.59MB/s]
# data/train-00000-of-00001-84acb79f6c6547(…): 100% 170M/170M [00:02<00:00, 70.5MB/s]
# data/validation-00000-of-00001-210cc51bf(…): 100% 38.3M/38.3M [00:01<00:00, 31.8MB/s]
# data/test-00000-of-00001-123f98d55067eb7(…): 100% 38.8M/38.8M [00:01<00:00, 38.7MB/s]
# Generating train split: 100% 99134/99134 [00:01<00:00, 72060.29 examples/s]
# Generating validation split: 100% 22184/22184 [00:00<00:00, 76724.84 examples/s]
# Generating test split: 100% 22498/22498 [00:00<00:00, 76110.79 examples/s]
# Step 1: Loading tokenizer and dataset completed
# Map: 100% 1000/1000 [00:01<00:00, 685.23 examples/s]
# Map: 100% 200/200 [00:00<00:00, 682.38 examples/s]
# Map: 100% 22498/22498 [00:34<00:00, 648.00 examples/s]
# Step 2: Preprocessing dataset completed
# Step 3: Setting up model_init wrapper for QDoRa completed
# config.json: 100% 702/702 [00:00<00:00, 6.40MB/s]
# pytorch_model.bin: 100% 904M/904M [00:05<00:00, 181MB/s]
# model.safetensors:  22% 201M/904M [00:01<00:02, 259MB/s]Step 4: Setting up Training hyperparams completed
# /content/ViT5_Base_QLoRa_VNDS/scripts/hp_search/hp_search.py:203: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(
# model.safetensors:  74% 671M/904M [00:05<00:01, 191MB/s]Step 5: Start hyperparameters search with 5 trials...
# [I 2026-03-13 03:40:25,562] A new study created in memory with name: no-name-4f9d8544-05a7-4f07-9981-96f08ac8897c
# model.safetensors: 100% 904M/904M [00:08<00:00, 108MB/s]
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# {'loss': 6.0886, 'grad_norm': nan, 'learning_rate': 3.503727354490535e-05, 'epoch': 0.4}
# {'loss': 5.5074, 'grad_norm': 2.090115547180176, 'learning_rate': 2.7345847456151173e-05, 'epoch': 0.8}
#  50% 63/126 [03:09<02:45,  2.63s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:07,  2.88it/s]
#  12% 3/25 [00:01<00:10,  2.05it/s]
#  16% 4/25 [00:02<00:11,  1.79it/s]
#  20% 5/25 [00:02<00:11,  1.67it/s]
#  24% 6/25 [00:03<00:11,  1.60it/s]
#  28% 7/25 [00:04<00:11,  1.55it/s]
#  32% 8/25 [00:04<00:11,  1.52it/s]
#  36% 9/25 [00:05<00:10,  1.50it/s]
#  40% 10/25 [00:06<00:10,  1.49it/s]
#  44% 11/25 [00:06<00:08,  1.57it/s]
#  48% 12/25 [00:07<00:08,  1.54it/s]
#  52% 13/25 [00:08<00:07,  1.52it/s]
#  56% 14/25 [00:08<00:06,  1.66it/s]
#  60% 15/25 [00:09<00:06,  1.59it/s]
#  64% 16/25 [00:09<00:05,  1.55it/s]
#  68% 17/25 [00:10<00:05,  1.55it/s]
#  72% 18/25 [00:11<00:04,  1.53it/s]
#  76% 19/25 [00:11<00:03,  1.51it/s]
#  80% 20/25 [00:12<00:03,  1.50it/s]
#  84% 21/25 [00:13<00:02,  1.49it/s]
#  88% 22/25 [00:13<00:02,  1.49it/s]
#  92% 23/25 [00:14<00:01,  1.48it/s]
#  96% 24/25 [00:15<00:00,  1.48it/s]
#
# {'eval_loss': 5.187114238739014, 'eval_runtime': 16.6707, 'eval_samples_per_second': 11.997, 'eval_steps_per_second': 1.5, 'epoch': 1.0}
#  50% 63/126 [03:26<02:45,  2.63s/it]
# 100% 25/25 [00:16<00:00,  1.48it/s]
# {'loss': 5.2237, 'grad_norm': 1.9814364910125732, 'learning_rate': 1.567261330550107e-05, 'epoch': 1.19}
# {'loss': 5.0309, 'grad_norm': 1.6471843719482422, 'learning_rate': 5.112954882868359e-06, 'epoch': 1.59}
# {'loss': 4.9716, 'grad_norm': 1.5339325666427612, 'learning_rate': 1.0207280683675931e-07, 'epoch': 1.99}
# 100% 126/126 [06:36<00:00,  2.53s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:07,  2.90it/s]
#  12% 3/25 [00:01<00:11,  1.99it/s]
#  16% 4/25 [00:02<00:11,  1.79it/s]
#  20% 5/25 [00:02<00:11,  1.67it/s]
#  24% 6/25 [00:03<00:11,  1.60it/s]
#  28% 7/25 [00:04<00:11,  1.55it/s]
#  32% 8/25 [00:04<00:11,  1.52it/s]
#  36% 9/25 [00:05<00:10,  1.49it/s]
#  40% 10/25 [00:06<00:10,  1.48it/s]
#  44% 11/25 [00:06<00:08,  1.56it/s]
#  48% 12/25 [00:07<00:08,  1.54it/s]
#  52% 13/25 [00:08<00:07,  1.53it/s]
#  56% 14/25 [00:08<00:06,  1.67it/s]
#  60% 15/25 [00:09<00:06,  1.62it/s]
#  64% 16/25 [00:09<00:05,  1.58it/s]
#  68% 17/25 [00:10<00:05,  1.55it/s]
#  72% 18/25 [00:11<00:04,  1.52it/s]
#  76% 19/25 [00:11<00:04,  1.50it/s]
#  80% 20/25 [00:12<00:03,  1.49it/s]
#  84% 21/25 [00:13<00:02,  1.46it/s]
#  88% 22/25 [00:14<00:02,  1.46it/s]
#  92% 23/25 [00:14<00:01,  1.48it/s]
#  96% 24/25 [00:15<00:00,  1.47it/s]
#
# {'eval_loss': 4.9683685302734375, 'eval_runtime': 16.7662, 'eval_samples_per_second': 11.929, 'eval_steps_per_second': 1.491, 'epoch': 2.0}
# 100% 126/126 [06:53<00:00,  2.53s/it]
# 100% 25/25 [00:16<00:00,  1.48it/s]
# {'train_runtime': 413.6566, 'train_samples_per_second': 4.835, 'train_steps_per_second': 0.305, 'train_loss': 5.360370461902921, 'epoch': 2.0}
# 100% 126/126 [06:53<00:00,  3.28s/it]
# [I 2026-03-13 03:47:23,152] Trial 0 finished with value: 4.9683685302734375 and parameters: {'learning_rate': 3.6647795909142815e-05}. Best is trial 0 with value: 4.9683685302734375.
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# {'loss': 5.2526, 'grad_norm': 1.3685438632965088, 'learning_rate': 0.0003690541506475463, 'epoch': 0.4}
# {'loss': 3.779, 'grad_norm': 0.9691756367683411, 'learning_rate': 0.0002835713056401913, 'epoch': 0.8}
#  50% 63/126 [03:08<02:42,  2.58s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:07,  2.89it/s]
#  12% 3/25 [00:01<00:10,  2.03it/s]
#  16% 4/25 [00:02<00:11,  1.79it/s]
#  20% 5/25 [00:02<00:12,  1.66it/s]
#  24% 6/25 [00:03<00:11,  1.60it/s]
#  28% 7/25 [00:04<00:11,  1.55it/s]
#  32% 8/25 [00:04<00:11,  1.52it/s]
#  36% 9/25 [00:05<00:10,  1.50it/s]
#  40% 10/25 [00:06<00:10,  1.49it/s]
#  44% 11/25 [00:06<00:08,  1.56it/s]
#  48% 12/25 [00:07<00:08,  1.54it/s]
#  52% 13/25 [00:08<00:07,  1.53it/s]
#  56% 14/25 [00:08<00:06,  1.68it/s]
#  60% 15/25 [00:09<00:06,  1.63it/s]
#  64% 16/25 [00:09<00:05,  1.58it/s]
#  68% 17/25 [00:10<00:05,  1.55it/s]
#  72% 18/25 [00:11<00:04,  1.53it/s]
#  76% 19/25 [00:11<00:03,  1.51it/s]
#  80% 20/25 [00:12<00:03,  1.48it/s]
#  84% 21/25 [00:13<00:02,  1.47it/s]
#  88% 22/25 [00:13<00:02,  1.46it/s]
#  92% 23/25 [00:14<00:01,  1.47it/s]
#  96% 24/25 [00:15<00:00,  1.47it/s]
#
# {'eval_loss': 3.4488365650177, 'eval_runtime': 16.7204, 'eval_samples_per_second': 11.961, 'eval_steps_per_second': 1.495, 'epoch': 1.0}
#  50% 63/126 [03:25<02:42,  2.58s/it]
# 100% 25/25 [00:16<00:00,  1.47it/s]
# {'loss': 3.5668, 'grad_norm': 1.0019478797912598, 'learning_rate': 0.00016005107416855766, 'epoch': 1.19}
# {'loss': 3.4455, 'grad_norm': 0.9708652496337891, 'learning_rate': 5.0373638820408444e-05, 'epoch': 1.59}
# {'loss': 3.4972, 'grad_norm': 0.956560492515564, 'learning_rate': 6.050189338489314e-07, 'epoch': 1.99}
# 100% 126/126 [06:33<00:00,  2.53s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:07,  2.92it/s]
#  12% 3/25 [00:01<00:10,  2.05it/s]
#  16% 4/25 [00:02<00:11,  1.79it/s]
#  20% 5/25 [00:02<00:12,  1.65it/s]
#  24% 6/25 [00:03<00:11,  1.59it/s]
#  28% 7/25 [00:04<00:11,  1.52it/s]
#  32% 8/25 [00:04<00:11,  1.52it/s]
#  36% 9/25 [00:05<00:10,  1.50it/s]
#  40% 10/25 [00:06<00:10,  1.49it/s]
#  44% 11/25 [00:06<00:08,  1.56it/s]
#  48% 12/25 [00:07<00:08,  1.54it/s]
#  52% 13/25 [00:08<00:07,  1.53it/s]
#  56% 14/25 [00:08<00:06,  1.68it/s]
#  60% 15/25 [00:09<00:06,  1.62it/s]
#  64% 16/25 [00:09<00:05,  1.58it/s]
#  68% 17/25 [00:10<00:05,  1.55it/s]
#  72% 18/25 [00:11<00:04,  1.52it/s]
#  76% 19/25 [00:11<00:03,  1.51it/s]
#  80% 20/25 [00:12<00:03,  1.50it/s]
#  84% 21/25 [00:13<00:02,  1.49it/s]
#  88% 22/25 [00:13<00:02,  1.49it/s]
#  92% 23/25 [00:14<00:01,  1.48it/s]
#  96% 24/25 [00:15<00:00,  1.47it/s]
#
# {'eval_loss': 3.3682258129119873, 'eval_runtime': 16.6776, 'eval_samples_per_second': 11.992, 'eval_steps_per_second': 1.499, 'epoch': 2.0}
# 100% 126/126 [06:50<00:00,  2.53s/it]
# 100% 25/25 [00:16<00:00,  1.46it/s]
# {'train_runtime': 411.057, 'train_samples_per_second': 4.866, 'train_steps_per_second': 0.307, 'train_loss': 3.9037846610659646, 'epoch': 2.0}
# 100% 126/126 [06:51<00:00,  3.26s/it]
# [I 2026-03-13 03:54:17,808] Trial 1 finished with value: 3.3682258129119873 and parameters: {'learning_rate': 0.00038601808371359277}. Best is trial 1 with value: 3.3682258129119873.
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# {'loss': 6.168, 'grad_norm': 3.468181848526001, 'learning_rate': 2.15833350582538e-05, 'epoch': 0.4}
# {'loss': 5.7539, 'grad_norm': 2.443725347518921, 'learning_rate': 1.7009304842669048e-05, 'epoch': 0.8}
#  50% 63/126 [03:08<02:43,  2.59s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:07,  2.88it/s]
#  12% 3/25 [00:01<00:10,  2.06it/s]
#  16% 4/25 [00:02<00:11,  1.77it/s]
#  20% 5/25 [00:02<00:12,  1.65it/s]
#  24% 6/25 [00:03<00:12,  1.58it/s]
#  28% 7/25 [00:04<00:11,  1.55it/s]
#  32% 8/25 [00:04<00:11,  1.52it/s]
#  36% 9/25 [00:05<00:10,  1.49it/s]
#  40% 10/25 [00:06<00:10,  1.48it/s]
#  44% 11/25 [00:06<00:08,  1.56it/s]
#  48% 12/25 [00:07<00:08,  1.54it/s]
#  52% 13/25 [00:08<00:07,  1.53it/s]
#  56% 14/25 [00:08<00:06,  1.68it/s]
#  60% 15/25 [00:09<00:06,  1.63it/s]
#  64% 16/25 [00:09<00:05,  1.57it/s]
#  68% 17/25 [00:10<00:05,  1.55it/s]
#  72% 18/25 [00:11<00:04,  1.53it/s]
#  76% 19/25 [00:11<00:03,  1.51it/s]
#  80% 20/25 [00:12<00:03,  1.50it/s]
#  84% 21/25 [00:13<00:02,  1.49it/s]
#  88% 22/25 [00:13<00:02,  1.46it/s]
#  92% 23/25 [00:14<00:01,  1.47it/s]
#  96% 24/25 [00:15<00:00,  1.46it/s]
# 100% 25/25 [00:16<00:00,  1.46it/s]
# {'eval_loss': 5.581460952758789, 'eval_runtime': 16.6993, 'eval_samples_per_second': 11.977, 'eval_steps_per_second': 1.497, 'epoch': 1.0}
#
#  50% 63/126 [03:25<02:43,  2.59s/it]
# {'loss': 5.5609, 'grad_norm': 4.970513820648193, 'learning_rate': 9.89553345951309e-06, 'epoch': 1.19}
# {'loss': 5.3964, 'grad_norm': 2.3629331588745117, 'learning_rate': 3.3405972918401786e-06, 'epoch': 1.59}
# {'loss': 5.3299, 'grad_norm': 3.1575450897216797, 'learning_rate': 9.765896878689699e-08, 'epoch': 1.99}
# 100% 126/126 [06:35<00:00,  2.55s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:07,  2.91it/s]
#  12% 3/25 [00:01<00:10,  2.06it/s]
#  16% 4/25 [00:02<00:11,  1.79it/s]
#  20% 5/25 [00:02<00:12,  1.66it/s]
#  24% 6/25 [00:03<00:11,  1.60it/s]
#  28% 7/25 [00:04<00:11,  1.54it/s]
#  32% 8/25 [00:04<00:11,  1.51it/s]
#  36% 9/25 [00:05<00:10,  1.47it/s]
#  40% 10/25 [00:06<00:10,  1.47it/s]
#  44% 11/25 [00:06<00:08,  1.56it/s]
#  48% 12/25 [00:07<00:08,  1.55it/s]
#  52% 13/25 [00:08<00:07,  1.53it/s]
#  56% 14/25 [00:08<00:06,  1.67it/s]
#  60% 15/25 [00:09<00:06,  1.63it/s]
#  64% 16/25 [00:09<00:05,  1.57it/s]
#  68% 17/25 [00:10<00:05,  1.54it/s]
#  72% 18/25 [00:11<00:04,  1.53it/s]
#  76% 19/25 [00:11<00:03,  1.51it/s]
#  80% 20/25 [00:12<00:03,  1.50it/s]
#  84% 21/25 [00:13<00:02,  1.49it/s]
#  88% 22/25 [00:13<00:02,  1.47it/s]
#  92% 23/25 [00:14<00:01,  1.48it/s]
#  96% 24/25 [00:15<00:00,  1.47it/s]
# 100% 25/25 [00:16<00:00,  1.47it/s]
# {'eval_loss': 5.3317646980285645, 'eval_runtime': 16.7128, 'eval_samples_per_second': 11.967, 'eval_steps_per_second': 1.496, 'epoch': 2.0}
#
# 100% 126/126 [06:52<00:00,  2.55s/it]
# {'train_runtime': 412.6967, 'train_samples_per_second': 4.846, 'train_steps_per_second': 0.305, 'train_loss': 5.638621413518512, 'epoch': 2.0}
# 100% 126/126 [06:52<00:00,  3.28s/it]
# [I 2026-03-13 04:01:14,120] Trial 2 finished with value: 5.3317646980285645 and parameters: {'learning_rate': 2.245210054411787e-05}. Best is trial 1 with value: 3.3682258129119873.
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# {'loss': 6.1942, 'grad_norm': 3.4725441932678223, 'learning_rate': 1.656581973854065e-05, 'epoch': 0.4}
# {'loss': 5.8351, 'grad_norm': 2.806191921234131, 'learning_rate': 1.29292702805667e-05, 'epoch': 0.8}
#  50% 63/126 [03:09<02:45,  2.63s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:07,  2.92it/s]
#  12% 3/25 [00:01<00:10,  2.06it/s]
#  16% 4/25 [00:02<00:11,  1.79it/s]
#  20% 5/25 [00:02<00:12,  1.64it/s]
#  24% 6/25 [00:03<00:11,  1.59it/s]
#  28% 7/25 [00:04<00:11,  1.53it/s]
#  32% 8/25 [00:04<00:11,  1.48it/s]
#  36% 9/25 [00:05<00:10,  1.49it/s]
#  40% 10/25 [00:06<00:10,  1.48it/s]
#  44% 11/25 [00:06<00:09,  1.55it/s]
#  48% 12/25 [00:07<00:08,  1.54it/s]
#  52% 13/25 [00:08<00:07,  1.53it/s]
#  56% 14/25 [00:08<00:06,  1.68it/s]
#  60% 15/25 [00:09<00:06,  1.62it/s]
#  64% 16/25 [00:09<00:05,  1.58it/s]
#  68% 17/25 [00:10<00:05,  1.54it/s]
#  72% 18/25 [00:11<00:04,  1.52it/s]
#  76% 19/25 [00:11<00:03,  1.50it/s]
#  80% 20/25 [00:12<00:03,  1.50it/s]
#  84% 21/25 [00:13<00:02,  1.49it/s]
#  88% 22/25 [00:13<00:02,  1.49it/s]
#  92% 23/25 [00:14<00:01,  1.48it/s]
#  96% 24/25 [00:15<00:00,  1.46it/s]
# 100% 25/25 [00:16<00:00,  1.47it/s]
# {'eval_loss': 5.697193622589111, 'eval_runtime': 16.7181, 'eval_samples_per_second': 11.963, 'eval_steps_per_second': 1.495, 'epoch': 1.0}
#
#  50% 63/126 [03:25<02:45,  2.63s/it]
# {'loss': 5.6926, 'grad_norm': 3.4293978214263916, 'learning_rate': 7.410099604868833e-06, 'epoch': 1.19}
# {'loss': 5.5583, 'grad_norm': 3.047431468963623, 'learning_rate': 2.4174337884005937e-06, 'epoch': 1.59}
# {'loss': 5.4964, 'grad_norm': 2.7304298877716064, 'learning_rate': 4.8260596421621537e-08, 'epoch': 1.99}
# 100% 126/126 [06:37<00:00,  2.56s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:07,  2.91it/s]
#  12% 3/25 [00:01<00:10,  2.05it/s]
#  16% 4/25 [00:02<00:11,  1.79it/s]
#  20% 5/25 [00:02<00:11,  1.67it/s]
#  24% 6/25 [00:03<00:11,  1.60it/s]
#  28% 7/25 [00:04<00:11,  1.55it/s]
#  32% 8/25 [00:04<00:11,  1.52it/s]
#  36% 9/25 [00:05<00:10,  1.50it/s]
#  40% 10/25 [00:06<00:10,  1.47it/s]
#  44% 11/25 [00:06<00:09,  1.54it/s]
#  48% 12/25 [00:07<00:08,  1.53it/s]
#  52% 13/25 [00:08<00:08,  1.50it/s]
#  56% 14/25 [00:08<00:06,  1.67it/s]
#  60% 15/25 [00:09<00:06,  1.61it/s]
#  64% 16/25 [00:09<00:05,  1.57it/s]
#  68% 17/25 [00:10<00:05,  1.55it/s]
#  72% 18/25 [00:11<00:04,  1.52it/s]
#  76% 19/25 [00:11<00:03,  1.51it/s]
#  80% 20/25 [00:12<00:03,  1.50it/s]
#  84% 21/25 [00:13<00:02,  1.49it/s]
#  88% 22/25 [00:13<00:02,  1.48it/s]
#  92% 23/25 [00:14<00:01,  1.48it/s]
#  96% 24/25 [00:15<00:00,  1.47it/s]
# 100% 25/25 [00:16<00:00,  1.47it/s]
# {'eval_loss': 5.564395904541016, 'eval_runtime': 16.7194, 'eval_samples_per_second': 11.962, 'eval_steps_per_second': 1.495, 'epoch': 2.0}
#
# 100% 126/126 [06:53<00:00,  2.56s/it]
# {'train_runtime': 414.1126, 'train_samples_per_second': 4.83, 'train_steps_per_second': 0.304, 'train_loss': 5.75245007257613, 'epoch': 2.0}
# 100% 126/126 [06:54<00:00,  3.29s/it]
# [I 2026-03-13 04:08:11,800] Trial 3 finished with value: 5.564395904541016 and parameters: {'learning_rate': 1.7327283758754787e-05}. Best is trial 1 with value: 3.3682258129119873.
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# {'loss': 5.5531, 'grad_norm': 1.5466965436935425, 'learning_rate': 0.0001874430037373573, 'epoch': 0.4}
# {'loss': 4.2398, 'grad_norm': 1.317232370376587, 'learning_rate': 0.0001440261739629755, 'epoch': 0.8}
#  50% 63/126 [03:09<02:46,  2.64s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:07,  2.92it/s]
#  12% 3/25 [00:01<00:10,  2.06it/s]
#  16% 4/25 [00:02<00:11,  1.79it/s]
#  20% 5/25 [00:02<00:11,  1.67it/s]
#  24% 6/25 [00:03<00:11,  1.60it/s]
#  28% 7/25 [00:04<00:11,  1.55it/s]
#  32% 8/25 [00:04<00:11,  1.52it/s]
#  36% 9/25 [00:05<00:10,  1.50it/s]
#  40% 10/25 [00:06<00:10,  1.47it/s]
#  44% 11/25 [00:06<00:09,  1.55it/s]
#  48% 12/25 [00:07<00:08,  1.50it/s]
#  52% 13/25 [00:08<00:08,  1.49it/s]
#  56% 14/25 [00:08<00:06,  1.67it/s]
#  60% 15/25 [00:09<00:06,  1.62it/s]
#  64% 16/25 [00:09<00:05,  1.57it/s]
#  68% 17/25 [00:10<00:05,  1.54it/s]
#  72% 18/25 [00:11<00:04,  1.52it/s]
#  76% 19/25 [00:11<00:03,  1.51it/s]
#  80% 20/25 [00:12<00:03,  1.49it/s]
#  84% 21/25 [00:13<00:02,  1.49it/s]
#  88% 22/25 [00:13<00:02,  1.49it/s]
#  92% 23/25 [00:14<00:01,  1.48it/s]
#  96% 24/25 [00:15<00:00,  1.48it/s]
# 100% 25/25 [00:16<00:00,  1.48it/s]
# {'eval_loss': 3.7002854347229004, 'eval_runtime': 16.7175, 'eval_samples_per_second': 11.964, 'eval_steps_per_second': 1.495, 'epoch': 1.0}
#
#  50% 63/126 [03:26<02:46,  2.64s/it]
# {'loss': 3.8434, 'grad_norm': 1.2008761167526245, 'learning_rate': 8.129011431223817e-05, 'epoch': 1.19}
# {'loss': 3.6555, 'grad_norm': 1.1680642366409302, 'learning_rate': 2.5584825839543456e-05, 'epoch': 1.59}
# {'loss': 3.6937, 'grad_norm': 1.1994794607162476, 'learning_rate': 3.0728977327482383e-07, 'epoch': 1.99}
# 100% 126/126 [06:36<00:00,  2.58s/it]
#   0% 0/25 [00:00<?, ?it/s]
#   8% 2/25 [00:00<00:07,  2.89it/s]
#  12% 3/25 [00:01<00:10,  2.06it/s]
#  16% 4/25 [00:02<00:11,  1.79it/s]
#  20% 5/25 [00:02<00:11,  1.67it/s]
#  24% 6/25 [00:03<00:11,  1.60it/s]
#  28% 7/25 [00:04<00:11,  1.55it/s]
#  32% 8/25 [00:04<00:11,  1.52it/s]
#  36% 9/25 [00:05<00:10,  1.49it/s]
#  40% 10/25 [00:06<00:10,  1.48it/s]
#  44% 11/25 [00:06<00:08,  1.56it/s]
#  48% 12/25 [00:07<00:08,  1.54it/s]
#  52% 13/25 [00:08<00:07,  1.53it/s]
#  56% 14/25 [00:08<00:06,  1.68it/s]
#  60% 15/25 [00:09<00:06,  1.61it/s]
#  64% 16/25 [00:09<00:05,  1.55it/s]
#  68% 17/25 [00:10<00:05,  1.53it/s]
#  72% 18/25 [00:11<00:04,  1.49it/s]
#  76% 19/25 [00:11<00:03,  1.50it/s]
#  80% 20/25 [00:12<00:03,  1.49it/s]
#  84% 21/25 [00:13<00:02,  1.49it/s]
#  88% 22/25 [00:13<00:02,  1.48it/s]
#  92% 23/25 [00:14<00:01,  1.48it/s]
#  96% 24/25 [00:15<00:00,  1.47it/s]
# 100% 25/25 [00:16<00:00,  1.47it/s]
# {'eval_loss': 3.544600486755371, 'eval_runtime': 16.7282, 'eval_samples_per_second': 11.956, 'eval_steps_per_second': 1.494, 'epoch': 2.0}
#
# 100% 126/126 [06:53<00:00,  2.58s/it]
# {'train_runtime': 413.7854, 'train_samples_per_second': 4.833, 'train_steps_per_second': 0.305, 'train_loss': 4.192075649897258, 'epoch': 2.0}
# 100% 126/126 [06:53<00:00,  3.28s/it]
# [I 2026-03-13 04:15:09,328] Trial 4 finished with value: 3.544600486755371 and parameters: {'learning_rate': 0.00019605900375664978}. Best is trial 1 with value: 3.3682258129119873.
# ==================================================
# Hyperparameters searching completed!
# Best hp found: {'learning_rate': 0.00038601808371359277}
# Best eval_loss: 3.3682258129119873
# ==================================================
# === FINISH ===
