# %%
# !git clone https://github.com/VietAnh-AI2-UET/ViT5_Base_QLoRa_VNDS.git
# Out:
# Cloning into 'ViT5_Base_QLoRa_VNDS'...
# remote: Enumerating objects: 289, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (50/50), done.
# remote: Total 289 (delta 20), reused 49 (delta 11), pack-reused 227 (from 1)
# Receiving objects: 100% (289/289), 265.16 KiB | 9.82 MiB/s, done.
# Resolving deltas: 100% (107/107), done.

# %%
# %cd ViT5_Base_QLoRa_VNDS
# Out:
# /content/ViT5_Base_QLoRa_VNDS

# %%
# !git checkout hp_search
# Out:
# Branch 'hp_search' set up to track remote branch 'hp_search' from 'origin'.
# Switched to a new branch 'hp_search'

# %%
# !chmod +x ./runner/hp_search_runner.sh

# %%
# !./runner/hp_search_runner.sh
# Out:
# === SETTING UP HYPERPARAMS SEARCHING EXPERIMENT ===
# Installing gettext library for bash
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# gettext is already the newest version (0.21-4ubuntu4).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# Installing requirements.txt
# Creating configs file at: /content/ViT5_Base_QLoRa_VNDS/configs/hp_search_exp/adalora_hp_search_configs.yaml
# Start running /content/ViT5_Base_QLoRa_VNDS/scripts/hp_search/adalora_hp_search.py
# 2026-03-22 01:48:19.772853: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774144099.794573   12250 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774144099.801804   12250 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774144099.820427   12250 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774144099.820454   12250 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774144099.820458   12250 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774144099.820462   12250 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-22 01:48:19.825169: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ===== RUNNING TRAIN.PY =====
# Step 0: Loading configuration for VietAI/vit5-base fine-tuning completed
# STEP 1: LOADING TOKENIZER AND DATASET COMPLETED
# STEP 2: PREPROCESSING DATA COMPLETED
# STEP 3: SETTING UP VietAI/vit5-base QUANTIZATION (QAdaLoRA) COMPLETED
# STEP 4: SETTING UP HYPERPARAMS COMPLETED
# /content/ViT5_Base_QLoRa_VNDS/scripts/hp_search/adalora_hp_search.py:218: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Seq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = Seq2SeqTrainer(
# STEP 5: START HYPERPARAMETERS SEARCH WITH 5 TRIALS...
# [I 2026-03-22 01:48:38,533] A new study created in memory with name: no-name-556642b7-05e9-44c1-bc64-ce0c443b1eed
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# {'loss': 5.8002, 'grad_norm': 1.4523082971572876, 'learning_rate': 0.000298344835014907, 'epoch': 0.8}
# {'eval_loss': 4.636366367340088, 'eval_runtime': 16.0064, 'eval_samples_per_second': 12.495, 'eval_steps_per_second': 1.562, 'epoch': 1.0}
# {'loss': 4.5501, 'grad_norm': 0.6522583961486816, 'learning_rate': 5.5782644272188946e-05, 'epoch': 1.592}
# {'eval_loss': 4.050735950469971, 'eval_runtime': 16.0349, 'eval_samples_per_second': 12.473, 'eval_steps_per_second': 1.559, 'epoch': 2.0}
# {'train_runtime': 375.6716, 'train_samples_per_second': 5.324, 'train_steps_per_second': 0.335, 'train_loss': 4.988022758847191, 'epoch': 2.0}
# [I 2026-03-22 01:54:58,343] Trial 0 finished with value: 4.050735950469971 and parameters: {'learning_rate': 0.00039982965024964974}. Best is trial 0 with value: 4.050735950469971.
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# {'loss': 6.2111, 'grad_norm': 0.9262704849243164, 'learning_rate': 6.708835733534468e-05, 'epoch': 0.8}
# {'eval_loss': 6.0675811767578125, 'eval_runtime': 16.0477, 'eval_samples_per_second': 12.463, 'eval_steps_per_second': 1.558, 'epoch': 1.0}
# {'loss': 6.0398, 'grad_norm': 1.5430576801300049, 'learning_rate': 1.2543759880596023e-05, 'epoch': 1.592}
# {'eval_loss': 5.938500881195068, 'eval_runtime': 16.0266, 'eval_samples_per_second': 12.479, 'eval_steps_per_second': 1.56, 'epoch': 2.0}
# {'train_runtime': 374.9618, 'train_samples_per_second': 5.334, 'train_steps_per_second': 0.336, 'train_loss': 6.078304472423735, 'epoch': 2.0}
# [I 2026-03-22 02:01:17,453] Trial 1 finished with value: 5.938500881195068 and parameters: {'learning_rate': 8.99090961231962e-05}. Best is trial 0 with value: 4.050735950469971.
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# {'loss': 6.2312, 'grad_norm': 0.17936527729034424, 'learning_rate': 1.3278521447873071e-05, 'epoch': 0.8}
# {'eval_loss': 6.215276718139648, 'eval_runtime': 16.0554, 'eval_samples_per_second': 12.457, 'eval_steps_per_second': 1.557, 'epoch': 1.0}
# {'loss': 6.2478, 'grad_norm': 0.30354735255241394, 'learning_rate': 2.4827345790998014e-06, 'epoch': 1.592}
# {'eval_loss': 6.212396144866943, 'eval_runtime': 16.0534, 'eval_samples_per_second': 12.458, 'eval_steps_per_second': 1.557, 'epoch': 2.0}
# {'train_runtime': 374.8276, 'train_samples_per_second': 5.336, 'train_steps_per_second': 0.336, 'train_loss': 6.230265420580667, 'epoch': 2.0}
# [I 2026-03-22 02:07:36,215] Trial 2 finished with value: 6.212396144866943 and parameters: {'learning_rate': 1.779533601133161e-05}. Best is trial 0 with value: 4.050735950469971.
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# {'loss': 6.2297, 'grad_norm': 0.3158756196498871, 'learning_rate': 2.6575891976186013e-05, 'epoch': 0.8}
# {'eval_loss': 6.203656196594238, 'eval_runtime': 16.0577, 'eval_samples_per_second': 12.455, 'eval_steps_per_second': 1.557, 'epoch': 1.0}
# {'loss': 6.2305, 'grad_norm': 0.6684893369674683, 'learning_rate': 5.299214138594108e-06, 'epoch': 1.592}
# {'eval_loss': 6.186262130737305, 'eval_runtime': 16.031, 'eval_samples_per_second': 12.476, 'eval_steps_per_second': 1.559, 'epoch': 2.0}
# {'train_runtime': 374.3173, 'train_samples_per_second': 5.343, 'train_steps_per_second': 0.337, 'train_loss': 6.217180766756573, 'epoch': 2.0}
# [I 2026-03-22 02:13:54,777] Trial 3 finished with value: 6.186262130737305 and parameters: {'learning_rate': 3.561593279595405e-05}. Best is trial 0 with value: 4.050735950469971.
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# {'loss': 6.2237, 'grad_norm': 0.5969440937042236, 'learning_rate': 4.635515223525707e-05, 'epoch': 0.8}
# {'eval_loss': 6.157127857208252, 'eval_runtime': 16.0775, 'eval_samples_per_second': 12.44, 'eval_steps_per_second': 1.555, 'epoch': 1.0}
# {'loss': 6.1619, 'grad_norm': 1.3037233352661133, 'learning_rate': 8.667195351960113e-06, 'epoch': 1.592}
# {'eval_loss': 6.087986946105957, 'eval_runtime': 16.0307, 'eval_samples_per_second': 12.476, 'eval_steps_per_second': 1.56, 'epoch': 2.0}
# {'train_runtime': 374.4775, 'train_samples_per_second': 5.341, 'train_steps_per_second': 0.336, 'train_loss': 6.166077507866754, 'epoch': 2.0}
# [I 2026-03-22 02:20:13,292] Trial 4 finished with value: 6.087986946105957 and parameters: {'learning_rate': 6.212329536244872e-05}. Best is trial 0 with value: 4.050735950469971.
# ==================================================
# Hyperparameters searching completed!
# Best hp found: {'learning_rate': 0.00039982965024964974}
# Best eval_loss: 4.050735950469971
# ==================================================
# Thư mục 'AdaLORA_hp_search_checkpoint' đã được nén thành công thành 'AdaLORA_hp_search_checkpoint.zip'
# Bạn có thể tải tệp 'AdaLORA_hp_search_checkpoint.zip' từ phần duyệt tệp của Colab (biểu tượng thư mục ở bên trái).
# === FINISH ===
