# %%
# !git clone https://github.com/VietAnh-AI2-UET/ViT5_Base_QLoRa_VNDS.git
# Out:
# Cloning into 'ViT5_Base_QLoRa_VNDS'...
# remote: Enumerating objects: 51, done.
# remote: Counting objects: 100% (51/51), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 51 (delta 14), reused 43 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (51/51), 20.13 KiB | 6.71 MiB/s, done.
# Resolving deltas: 100% (14/14), done.

# %%
# %cd ViT5_Base_QLoRa_VNDS
# Out:
# /content/ViT5_Base_QLoRa_VNDS

# %%
# !git checkout qlora_vit5_baseline
# Out:
# Branch 'qlora_vit5_baseline' set up to track remote branch 'qlora_vit5_baseline' from 'origin'.
# Switched to a new branch 'qlora_vit5_baseline'

# %%
# !apt-get -q install -y gettext
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   gettext-base
# Suggested packages:
#   gettext-doc autopoint libasprintf-dev libgettextpo-dev
# The following NEW packages will be installed:
#   gettext gettext-base
# 0 upgraded, 2 newly installed, 0 to remove and 37 not upgraded.
# Need to get 906 kB of archives.
# After this operation, 2,990 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 gettext-base amd64 0.21-4ubuntu4 [37.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 gettext amd64 0.21-4ubuntu4 [868 kB]
# Fetched 906 kB in 1s (702 kB/s)
# Selecting previously unselected package gettext-base.
# (Reading database ... 121852 files and directories currently installed.)
# Preparing to unpack .../gettext-base_0.21-4ubuntu4_amd64.deb ...
# Unpacking gettext-base (0.21-4ubuntu4) ...
# Selecting previously unselected package gettext.
# Preparing to unpack .../gettext_0.21-4ubuntu4_amd64.deb ...
# Unpacking gettext (0.21-4ubuntu4) ...
# Setting up gettext-base (0.21-4ubuntu4) ...
# Setting up gettext (0.21-4ubuntu4) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link

# %%
# !pip install -q -r requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 15.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 16.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.7/153.7 kB 18.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.2/515.2 kB 49.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 15.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 10.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.0/201.0 kB 23.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 45.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 134.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.3/150.3 kB 18.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 84.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 89.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 114.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 135.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 kB 19.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.7/803.7 kB 42.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 7.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 93.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 16.6 MB/s eta 0:00:00
#   Building wheel for rouge_score (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.1 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.4.2 which is incompatible.
# dask-cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.
# bqplot 0.12.45 requires pandas<3.0.0,>=1.0.0, but you have pandas 3.0.1 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.10.0 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.4.2 which is incompatible.
# db-dtypes 1.5.0 requires pandas<3.0.0,>=1.5.3, but you have pandas 3.0.1 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.1 which is incompatible.
# gradio 5.50.0 requires pillow<12.0,>=8.0, but you have pillow 12.1.1 which is incompatible.

# %%
# !unzip QLoRa_ViT5_fine_tuned_archive_10Epochs.zip -d qlora_vit5_baseline
# Out:
# Archive:  QLoRa_ViT5_fine_tuned_archive_10Epochs.zip
#   inflating: qlora_vit5_baseline/adapter_config.json
#   inflating: qlora_vit5_baseline/README.md
#   inflating: qlora_vit5_baseline/spiece.model
#   inflating: qlora_vit5_baseline/tokenizer_config.json
#   inflating: qlora_vit5_baseline/adapter_model.safetensors
#   inflating: qlora_vit5_baseline/training_args.bin
#   inflating: qlora_vit5_baseline/special_tokens_map.json
#   inflating: qlora_vit5_baseline/tokenizer.json

# %%
!(echo "cat <<EOF"; cat configs/qlora_vit5/inferencing_configs.yaml.template; echo ""; echo "EOF") | bash > configs/qlora_vit5/inferencing_configs.yaml

# %%
# !python scripts/qlora_vit5/inference.py --config configs/qlora_vit5/inferencing_configs.yaml
# Out:
# 2026-03-01 02:10:46.158586: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772331046.179833    1572 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772331046.186810    1572 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772331046.204637    1572 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772331046.204662    1572 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772331046.204666    1572 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772331046.204670    1572 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-01 02:10:46.209282: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# README.md: 100% 748/748 [00:00<00:00, 6.69MB/s]
# data/train-00000-of-00001-84acb79f6c6547(…): 100% 170M/170M [00:02<00:00, 62.5MB/s]
# data/validation-00000-of-00001-210cc51bf(…): 100% 38.2M/38.3M [00:00<00:00, 42.6MB/s]
# data/test-00000-of-00001-123f98d55067eb7(…): 100% 38.8M/38.8M [00:00<00:00, 49.2MB/s]
# Generating train split: 100% 99134/99134 [00:03<00:00, 25963.03 examples/s]
# Generating validation split: 100% 22184/22184 [00:00<00:00, 51908.87 examples/s]
# Generating test split: 100% 22498/22498 [00:00<00:00, 31277.73 examples/s]
# config.json: 100% 702/702 [00:00<00:00, 4.87MB/s]
# pytorch_model.bin: 100% 904M/904M [00:08<00:00, 110MB/s]
# model.safetensors:  89% 805M/904M [00:08<00:00, 158MB/s]
# model.safetensors:  89% 805M/904M [00:09<00:01, 85.9MB/s]
#
# Generating summaries:   2% 1/50 [00:13<10:51, 13.31s/it]
# Generating summaries:   4% 2/50 [00:20<07:46,  9.72s/it]
# Generating summaries:   6% 3/50 [00:24<05:37,  7.17s/it]
# Generating summaries:   8% 4/50 [00:27<04:08,  5.40s/it]
# Generating summaries:  10% 5/50 [00:32<03:53,  5.18s/it]
# Generating summaries:  12% 6/50 [00:35<03:20,  4.55s/it]
# Generating summaries:  14% 7/50 [00:40<03:24,  4.77s/it]
# Generating summaries:  16% 8/50 [00:44<03:11,  4.55s/it]
# Generating summaries:  18% 9/50 [00:49<03:02,  4.46s/it]
# Generating summaries:  20% 10/50 [00:51<02:37,  3.93s/it]
# Generating summaries:  22% 11/50 [00:56<02:39,  4.08s/it]
# Generating summaries:  24% 12/50 [00:57<02:08,  3.38s/it]
# Generating summaries:  26% 13/50 [01:00<01:53,  3.07s/it]
# Generating summaries:  28% 14/50 [01:04<01:58,  3.29s/it]
# Generating summaries:  30% 15/50 [01:07<01:56,  3.32s/it]
# Generating summaries:  32% 16/50 [01:10<01:46,  3.13s/it]
# Generating summaries:  34% 17/50 [01:12<01:36,  2.93s/it]
# Generating summaries:  36% 18/50 [01:17<01:47,  3.36s/it]
# Generating summaries:  38% 19/50 [01:18<01:31,  2.94s/it]
# Generating summaries:  40% 20/50 [01:21<01:25,  2.85s/it]
# Generating summaries:  42% 21/50 [01:24<01:20,  2.78s/it]
# Generating summaries:  44% 22/50 [01:26<01:14,  2.67s/it]
# Generating summaries:  46% 23/50 [01:30<01:22,  3.05s/it]
# Generating summaries:  48% 24/50 [01:38<01:54,  4.40s/it]
# Generating summaries:  50% 25/50 [01:43<01:55,  4.63s/it]
# Generating summaries:  52% 26/50 [01:47<01:46,  4.45s/it]
# Generating summaries:  54% 27/50 [01:49<01:27,  3.78s/it]
# Generating summaries:  56% 28/50 [01:53<01:21,  3.69s/it]
# Generating summaries:  58% 29/50 [01:57<01:22,  3.95s/it]
# Generating summaries:  60% 30/50 [02:03<01:28,  4.44s/it]
# Generating summaries:  62% 31/50 [02:05<01:13,  3.88s/it]
# Generating summaries:  64% 32/50 [02:09<01:10,  3.94s/it]
# Generating summaries:  66% 33/50 [02:12<01:00,  3.55s/it]
# Generating summaries:  68% 34/50 [02:14<00:51,  3.20s/it]
# Generating summaries:  70% 35/50 [02:18<00:52,  3.49s/it]
# Generating summaries:  72% 36/50 [02:21<00:44,  3.21s/it]
# Generating summaries:  74% 37/50 [02:23<00:37,  2.87s/it]
# Generating summaries:  76% 38/50 [02:26<00:34,  2.89s/it]
# Generating summaries:  78% 39/50 [02:29<00:30,  2.80s/it]
# Generating summaries:  80% 40/50 [02:33<00:32,  3.21s/it]
# Generating summaries:  82% 41/50 [02:36<00:29,  3.31s/it]
# Generating summaries:  84% 42/50 [02:40<00:28,  3.52s/it]
# Generating summaries:  86% 43/50 [02:44<00:24,  3.48s/it]
# Generating summaries:  88% 44/50 [02:47<00:19,  3.29s/it]
# Generating summaries:  90% 45/50 [02:51<00:18,  3.64s/it]
# Generating summaries:  92% 46/50 [02:55<00:14,  3.72s/it]
# Generating summaries:  94% 47/50 [02:58<00:10,  3.42s/it]
# Generating summaries:  96% 48/50 [03:01<00:06,  3.37s/it]
# Generating summaries:  98% 49/50 [03:04<00:03,  3.19s/it]
# Generating summaries: 100% 50/50 [03:07<00:00,  3.75s/it]
# Downloading builder script: 6.14kB [00:00, 12.1MB/s]
# Downloading builder script: 7.95kB [00:00, 6.21MB/s]
# ROUGE Scores:
# rouge1: 0.5729
# rouge2: 0.2572
# rougeL: 0.3676
# rougeLsum: 0.3677
#
# Calculating BERTScore (this may take a while)...
# tokenizer_config.json: 100% 49.0/49.0 [00:00<00:00, 456kB/s]
# config.json: 100% 625/625 [00:00<00:00, 6.15MB/s]
# vocab.txt: 100% 996k/996k [00:00<00:00, 20.9MB/s]
# tokenizer.json: 100% 1.96M/1.96M [00:00<00:00, 17.6MB/s]
# model.safetensors: 100% 714M/714M [00:08<00:00, 84.3MB/s]
#
# BERTScore Results:
# BERTScore F1 (mean): 0.7604
# BERTScore Precision (mean): 0.7633
# BERTScore Recall (mean): 0.7582
