# %%
# !git clone https://github.com/VietAnh-AI2-UET/ViT5_Base_QLoRa_VNDS.git
# Out:
# Cloning into 'ViT5_Base_QLoRa_VNDS'...
# remote: Enumerating objects: 61, done.
# remote: Counting objects: 100% (61/61), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 61 (delta 19), reused 50 (delta 10), pack-reused 0 (from 0)
# Receiving objects: 100% (61/61), 23.58 KiB | 2.14 MiB/s, done.
# Resolving deltas: 100% (19/19), done.

# %%
# %cd ViT5_Base_QLoRa_VNDS
# Out:
# /content/ViT5_Base_QLoRa_VNDS

# %%
# !git checkout qdora_vit5
# Out:
# Branch 'qdora_vit5' set up to track remote branch 'qdora_vit5' from 'origin'.
# Switched to a new branch 'qdora_vit5'

# %%
# !apt-get install -y gettext
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   gettext-base
# Suggested packages:
#   gettext-doc autopoint libasprintf-dev libgettextpo-dev
# The following NEW packages will be installed:
#   gettext gettext-base
# 0 upgraded, 2 newly installed, 0 to remove and 37 not upgraded.
# Need to get 906 kB of archives.
# After this operation, 2,990 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 gettext-base amd64 0.21-4ubuntu4 [37.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 gettext amd64 0.21-4ubuntu4 [868 kB]
# Fetched 906 kB in 0s (2,717 kB/s)
# Selecting previously unselected package gettext-base.
# (Reading database ... 121852 files and directories currently installed.)
# Preparing to unpack .../gettext-base_0.21-4ubuntu4_amd64.deb ...
# Unpacking gettext-base (0.21-4ubuntu4) ...
# ...

# %%
# !pip install -q -r requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 7.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 10.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 14.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.7/153.7 kB 15.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.2/515.2 kB 37.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 12.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 7.5 MB/s eta 0:00:00
# ...

# %%
!(echo "cat <<EOF"; cat configs/qlora_vit5/training_configs.yaml.template; echo ""; echo "EOF") | bash > configs/qlora_vit5/training_configs.yaml

# %%
# !python scripts/qdora_vit5/train.py --config configs/qlora_vit5/training_configs.yaml
# Out:
# 2026-03-02 03:33:37.388584: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772422417.411168     707 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772422417.418830     707 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772422417.438160     707 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
import shutil

# Define the directory to save the model and the name for the zip file
save_directory = "./qlora_vit5_baseline"
zip_file_name = "fine_tuned_model_archive"

# Create a zip archive of the directory
shutil.make_archive(zip_file_name, 'zip', save_directory)

print(f"Thư mục '{save_directory}' đã được nén thành công thành '{zip_file_name}.zip'")
print(f"Bạn có thể tải tệp '{zip_file_name}.zip' từ phần duyệt tệp của Colab (biểu tượng thư mục ở bên trái).")
# Out:
# Thư mục './qlora_vit5_baseline' đã được nén thành công thành 'fine_tuned_model_archive.zip'
# Bạn có thể tải tệp 'fine_tuned_model_archive.zip' từ phần duyệt tệp của Colab (biểu tượng thư mục ở bên trái).
