# %%
# !git clone https://github.com/VietAnh-AI2-UET/ViT5_Base_QLoRa_VNDS.git
# Out:
# Cloning into 'ViT5_Base_QLoRa_VNDS'...
# remote: Enumerating objects: 89, done.
# remote: Counting objects: 100% (89/89), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 89 (delta 33), reused 74 (delta 20), pack-reused 0 (from 0)
# Receiving objects: 100% (89/89), 71.32 KiB | 5.49 MiB/s, done.
# Resolving deltas: 100% (33/33), done.

# %%
# %cd ViT5_Base_QLoRa_VNDS
# Out:
# /content/ViT5_Base_QLoRa_VNDS

# %%
# !git checkout qdora_vit5
# Out:
# Branch 'qdora_vit5' set up to track remote branch 'qdora_vit5' from 'origin'.
# Switched to a new branch 'qdora_vit5'

# %%
# !apt-get install gettext
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   gettext-base
# Suggested packages:
#   gettext-doc autopoint libasprintf-dev libgettextpo-dev
# The following NEW packages will be installed:
#   gettext gettext-base
# 0 upgraded, 2 newly installed, 0 to remove and 37 not upgraded.
# Need to get 906 kB of archives.
# After this operation, 2,990 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 gettext-base amd64 0.21-4ubuntu4 [37.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 gettext amd64 0.21-4ubuntu4 [868 kB]
# Fetched 906 kB in 0s (3,434 kB/s)
# Selecting previously unselected package gettext-base.
# (Reading database ... 121852 files and directories currently installed.)
# Preparing to unpack .../gettext-base_0.21-4ubuntu4_amd64.deb ...
# Unpacking gettext-base (0.21-4ubuntu4) ...
# ...

# %%
# !pip install -q -r requirements.txt
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 14.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 14.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.7/153.7 kB 17.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.2/515.2 kB 21.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 14.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 10.4 MB/s eta 0:00:00
# ...

# %%
# !unzip fine_tuned_model_archive.zip -d qdora_vit5_adapter
# Out:
# Archive:  fine_tuned_model_archive.zip
#   inflating: qdora_vit5_adapter/adapter_config.json
#   inflating: qdora_vit5_adapter/README.md
#   inflating: qdora_vit5_adapter/special_tokens_map.json
#   inflating: qdora_vit5_adapter/tokenizer.json
#   inflating: qdora_vit5_adapter/spiece.model
#   inflating: qdora_vit5_adapter/tokenizer_config.json
#   inflating: qdora_vit5_adapter/training_args.bin
#   inflating: qdora_vit5_adapter/adapter_model.safetensors

# %%
!(echo "cat <<EOF"; cat configs/qlora_vit5/inferencing_configs.yaml.template; echo ""; echo "EOF") | bash > configs/qlora_vit5/inferencing_configs.yaml

# %%
# !python scripts/qdora_vit5/inference.py --config configs/qlora_vit5/inferencing_configs.yaml --adapter_path qdora_vit5_adapter
# Out:
# 2026-03-03 03:05:16.174953: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772507116.195721    1529 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772507116.202502    1529 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772507116.219874    1529 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
