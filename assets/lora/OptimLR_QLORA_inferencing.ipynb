# %%
# !git clone https://github.com/VietAnh-AI2-UET/ViT5_Base_QLoRa_VNDS.git
# Out:
# Cloning into 'ViT5_Base_QLoRa_VNDS'...
# remote: Enumerating objects: 309, done.
# remote: Counting objects: 100% (82/82), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 309 (delta 30), reused 65 (delta 16), pack-reused 227 (from 1)
# Receiving objects: 100% (309/309), 268.78 KiB | 9.60 MiB/s, done.
# Resolving deltas: 100% (117/117), done.

# %%
# %cd ViT5_Base_QLoRa_VNDS
# Out:
# /content/ViT5_Base_QLoRa_VNDS

# %%
# !git checkout hp_search
# Out:
# Branch 'hp_search' set up to track remote branch 'hp_search' from 'origin'.
# Switched to a new branch 'hp_search'

# %%
adapter_zip_path = "/content/ViT5_Base_QLoRa_VNDS/OptimLR_QLORA_adapter.zip"
adapter_path = "./OptimLR_QLORA_adapter"

# !unzip $adapter_zip_path -d $adapter_path
# Out:
# Archive:  /content/ViT5_Base_QLoRa_VNDS/OptimLR_QLORA_adapter.zip
#   inflating: ./OptimLR_QLORA_adapter/adapter_config.json
#   inflating: ./OptimLR_QLORA_adapter/adapter_model.safetensors
#   inflating: ./OptimLR_QLORA_adapter/README.md
#   inflating: ./OptimLR_QLORA_adapter/spiece.model
#   inflating: ./OptimLR_QLORA_adapter/training_args.bin
#   inflating: ./OptimLR_QLORA_adapter/tokenizer_config.json
#   inflating: ./OptimLR_QLORA_adapter/special_tokens_map.json
#   inflating: ./OptimLR_QLORA_adapter/tokenizer.json

# %%
# %%writefile ./runner/infer_runner.sh
# #!/bin/bash
#
# # Dừng script ngay lập tức nếu có bất kỳ lỗi nào xảy ra
# set -e
#
# echo "=== SETTING UP INFERENCING ==="
#
# # --- IMPORTANT PATHS ---
# TEMPLATE_PATH="/content/ViT5_Base_QLoRa_VNDS/configs/baseline/inferencing_configs.yaml.template"
# CONFIG_PATH="/content/ViT5_Base_QLoRa_VNDS/configs/baseline/inferencing_configs.yaml"
# INFER_SCRIPT="/content/ViT5_Base_QLoRa_VNDS/scripts/baseline/inference.py"
# ADAPTER_PATH="./OptimLR_QLORA_adapter"
# # --------------------------------
#
# # install gettext for bash
# echo "Installing gettext library for bash"
# apt-get install gettext
#
# # install requirements.txt
# echo "Installing requirements.txt"
# pip install -qq -r requirements.txt
#
# # Sinh file cấu hình hoàn chỉnh từ file yaml template
# echo "Creating configs file at: $CONFIG_PATH"
#
# (echo "cat <<EOF"; cat $TEMPLATE_PATH; echo ""; echo "EOF") | bash > $CONFIG_PATH
#
# # Start inferencing
# echo "Start running $INFER_SCRIPT"
#
# python $INFER_SCRIPT --config $CONFIG_PATH --adapter_path $ADAPTER_PATH
#
# echo "=== FINISH ==="
# Out:
# Overwriting ./runner/infer_runner.sh

# %%
# !chmod +x ./runner/infer_runner.sh

# %%
# !./runner/infer_runner.sh
# Out:
# === SETTING UP INFERENCING ===
# Installing gettext library for bash
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   gettext-base
# Suggested packages:
#   gettext-doc autopoint libasprintf-dev libgettextpo-dev
# The following NEW packages will be installed:
#   gettext gettext-base
# 0 upgraded, 2 newly installed, 0 to remove and 37 not upgraded.
# Need to get 906 kB of archives.
# After this operation, 2,990 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 gettext-base amd64 0.21-4ubuntu4 [37.8 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 gettext amd64 0.21-4ubuntu4 [868 kB]
# Fetched 906 kB in 1s (1,141 kB/s)
# Selecting previously unselected package gettext-base.
# (Reading database ... 121852 files and directories currently installed.)
# Preparing to unpack .../gettext-base_0.21-4ubuntu4_amd64.deb ...
# Unpacking gettext-base (0.21-4ubuntu4) ...
# Selecting previously unselected package gettext.
# Preparing to unpack .../gettext_0.21-4ubuntu4_amd64.deb ...
# Unpacking gettext (0.21-4ubuntu4) ...
# Setting up gettext-base (0.21-4ubuntu4) ...
# Setting up gettext (0.21-4ubuntu4) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# Installing requirements.txt
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 10.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.1/75.1 kB 9.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.8/135.8 kB 16.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 380.9/380.9 kB 26.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 15.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.5/153.5 kB 18.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.2/515.2 kB 52.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.7/119.7 kB 16.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 11.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 142.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 201.0/201.0 kB 26.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 55.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 94.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 105.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.3/150.3 kB 20.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 77.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 100.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 413.9/413.9 kB 45.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 123.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 133.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 kB 20.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 12.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 803.7/803.7 kB 63.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 8.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 112.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 16.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.3/377.3 kB 42.7 MB/s eta 0:00:00
#   Building wheel for rouge_score (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.1 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.1 which is incompatible.
# gradio 5.50.0 requires pillow<12.0,>=8.0, but you have pillow 12.1.1 which is incompatible.
# bqplot 0.12.45 requires pandas<3.0.0,>=1.0.0, but you have pandas 3.0.1 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.4.2 which is incompatible.
# gcsfs 2025.3.0 requires fsspec==2025.3.0, but you have fsspec 2025.10.0 which is incompatible.
# dask-cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.1 which is incompatible.
# db-dtypes 1.5.0 requires pandas<3.0.0,>=1.5.3, but you have pandas 3.0.1 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.4.2 which is incompatible.
# Creating configs file at: /content/ViT5_Base_QLoRa_VNDS/configs/baseline/inferencing_configs.yaml
# Start running /content/ViT5_Base_QLoRa_VNDS/scripts/baseline/inference.py
# 2026-03-22 07:30:57.153887: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1774164657.189884    3963 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1774164657.200914    3963 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1774164657.229686    3963 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774164657.229724    3963 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774164657.229734    3963 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1774164657.229741    3963 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-22 07:30:57.236708: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# README.md: 100% 748/748 [00:00<00:00, 5.24MB/s]
# data/train-00000-of-00001-84acb79f6c6547(…): 100% 170M/170M [00:01<00:00, 92.9MB/s]
# data/validation-00000-of-00001-210cc51bf(…): 100% 38.3M/38.3M [00:00<00:00, 47.0MB/s]
# data/test-00000-of-00001-123f98d55067eb7(…): 100% 38.8M/38.8M [00:00<00:00, 63.6MB/s]
# Generating train split: 100% 99134/99134 [00:08<00:00, 11233.38 examples/s]
# Generating validation split: 100% 22184/22184 [00:00<00:00, 55490.15 examples/s]
# Generating test split: 100% 22498/22498 [00:00<00:00, 50959.31 examples/s]
# config.json: 100% 702/702 [00:00<00:00, 4.16MB/s]
# pytorch_model.bin: 100% 904M/904M [00:04<00:00, 196MB/s]
# model.safetensors: 100% 904M/904M [00:05<00:00, 180MB/s]
# Generating summaries: 100% 50/50 [03:42<00:00,  4.45s/it]
# Downloading builder script: 6.14kB [00:00, 17.7MB/s]
# Downloading builder script: 7.95kB [00:00, 20.7MB/s]
# ROUGE Scores:
# rouge1: 0.5700
# rouge2: 0.2470
# rougeL: 0.3621
# rougeLsum: 0.3627
#
# Calculating BERTScore (this may take a while)...
# tokenizer_config.json: 100% 49.0/49.0 [00:00<00:00, 290kB/s]
# config.json: 100% 625/625 [00:00<00:00, 4.91MB/s]
# vocab.txt: 996kB [00:00, 5.98MB/s]
# tokenizer.json: 1.96MB [00:00, 8.05MB/s]
# model.safetensors: 100% 714M/714M [00:05<00:00, 123MB/s]
#
# BERTScore Results:
# BERTScore F1 (mean): 0.7579
# BERTScore Precision (mean): 0.7617
# BERTScore Recall (mean): 0.7547
# === FINISH ===
